# %%
import csv
import pandas as pd
import re

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
# [227835 rows x 4 columns]

# %% [markdown]
# # START HERE

# %% [markdown]
# ## cleaning/rearranging

# %%
df["content"][0]
# Out:
# '                                 FINAL REPORT\n EXAMINATION:  CHEST (PA AND LAT)\n \n INDICATION:  ___F with new onset ascites  // eval for infection\n \n TECHNIQUE:  Chest PA and lateral\n \n COMPARISON:  None.\n \n FINDINGS: \n \n There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral\n nodular opacities that most likely represent nipple shadows. The\n cardiomediastinal silhouette is normal.  Clips project over the left lung,\n potentially within the breast. The imaged upper abdomen is unremarkable.\n Chronic deformity of the posterior left sixth and seventh ribs are noted.\n \n IMPRESSION: \n \n No acute cardiopulmonary process.\n'

# %%
def clean_text(text):
    #replace unwanted chars and whitespace
    cleaned_text = re.sub(r"[\n\r\t]+|___|//", " ", text)
    cleaned_text = re.sub(r"\s+", " ", cleaned_text)
    
    return cleaned_text.strip()

# %%
df['cleaned_content'] = df['content'].apply(clean_text)

# %%
df["cleaned_content"][0]
# Out:
# 'FINAL REPORT EXAMINATION: CHEST (PA AND LAT) INDICATION: F with new onset ascites eval for infection TECHNIQUE: Chest PA and lateral COMPARISON: None. FINDINGS: There is no focal consolidation, pleural effusion or pneumothorax. Bilateral nodular opacities that most likely represent nipple shadows. The cardiomediastinal silhouette is normal. Clips project over the left lung, potentially within the breast. The imaged upper abdomen is unremarkable. Chronic deformity of the posterior left sixth and seventh ribs are noted. IMPRESSION: No acute cardiopulmonary process.'

# %%
def remove_final_report(text):
    # regex patterns to drop cause no value
    pattern = r"FINAL REPORT|CHEST RADIOGRAPH PERFORMED ON|PORTABLE CHEST OF|PORTABLE AP CHEST X-RAY"
    cleaned_text = re.sub(pattern, "", text, flags=re.IGNORECASE)
    
    return cleaned_text.strip()

# %%
df['cleaned_content'] = df['cleaned_content'].apply(remove_final_report)

# %%
def clean_comparison(df):
    #edit messed up important labels
    df['cleaned_content'] = df['cleaned_content'].str.replace('OMPARISON', 'COMPARISON')
    df['cleaned_content'] = df['cleaned_content'].str.replace('COMPARISONS', 'COMPARISON')
    df['cleaned_content'] = df['cleaned_content'].str.replace('INDCATION', 'INDICATION')
    df['cleaned_content'] = df['cleaned_content'].str.replace('IDICATION', 'INDICATION')
    return df

# %%
clean_comparison(df)
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...
# ...                                                   ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...
# 227832  CCOMPARISON: radiograph. FINDINGS: There has b...
# 227833  CCOMPARISON: Prior chest radiograph from earli...
# 227834  INDICATION: -year-old female intubated for hea...
#
# [227835 rows x 5 columns]

# %%
def clean_up_comparison(text):
    # fix the double c
    pattern = r"CCOMPARISON"
    cleaned_text = re.sub(pattern, "COMPARISON", text, flags=re.IGNORECASE)
    return cleaned_text.strip()

# %%
df['cleaned_content'] = df['cleaned_content'].apply(clean_up_comparison)

# %%
df["cleaned_content"][0]
# Out:
# 'EXAMINATION: CHEST (PA AND LAT) INDICATION: F with new onset ascites eval for infection TECHNIQUE: Chest PA and lateral COMPARISON: None. FINDINGS: There is no focal consolidation, pleural effusion or pneumothorax. Bilateral nodular opacities that most likely represent nipple shadows. The cardiomediastinal silhouette is normal. Clips project over the left lung, potentially within the breast. The imaged upper abdomen is unremarkable. Chronic deformity of the posterior left sixth and seventh ribs are noted. IMPRESSION: No acute cardiopulmonary process.'

# %%
df['cleaned_content'][227833]
# Out:
# 'COMPARISON: Prior chest radiograph from earlier same day. CLINICAL HISTORY: Transfer from outside hospital with intubation, assess position of tube. FINDINGS: Portable supine AP view of the chest provided demonstrates an endotracheal tube with tip positioned approximately 3.5 cm above the carina. The NG tube courses into the left upper abdomen. There is bibasilar atelectasis. Heart and mediastinal contour appears grossly unremarkable. The bony structures appear intact. IMPRESSION: Appropriately positioned ET and NG tubes. Bibasilar atelectasis.'

# %%
df['cleaned_content'][227832]
# Out:
# 'COMPARISON: radiograph. FINDINGS: There has been interval extubation and improved lung volumes compared to the recent radiograph. Bibasilar atelectasis has nearly resolved with residual patchy atelectasis remaining in the right lower lobe and only minimal residual linear atelectasis in the left lower lobe. Apparent rightward deviation of the trachea is likely due to mild patient rotation and curvature of the spine, as there is no evidence of a discrete paratracheal mass on recent neck CTA of . Cardiac silhouette is stable in size. No pleural effusion or pneumothorax.'

# %%
df['cleaned_content'][227830]
# Out:
# 'INDICATION: Patient with intubation, evaluation for ETT placement. COMPARISON: None. FINDINGS: ET tube ends 4.7 cm above the carina. NG tube is in the stomach. The lungs are otherwise clear. Elevation of right hemidiaphragm is mild. There is no pneumothorax or pleural effusion. Mediastinal and cardiac contours are normal. CONCLUSION: 1. Lines and tubes are in adequate position. 2. The rest of the exam is unremarkable.'

# %%
df['content'][227830]
# Out:
# '                                 FINAL REPORT\n PORTABLE AP CHEST X-RAY\n \n INDICATION:  Patient with intubation, evaluation for ETT placement.\n \n COMPARISON:  None.\n \n FINDINGS:\n \n ET tube ends 4.7 cm above the carina.  NG tube is in the stomach.  The lungs\n are otherwise clear.  Elevation of right hemidiaphragm is mild.  There is no\n pneumothorax or pleural effusion.  Mediastinal and cardiac contours are\n normal.\n \n CONCLUSION:\n \n 1.  Lines and tubes are in adequate position.\n \n 2.  The rest of the exam is unremarkable.\n'

# %%
headers = []
for content in df['cleaned_content']:
    matches = re.findall(r'^([A-Z][A-Z\s]+:)', content, re.MULTILINE)
    headers.extend(matches)

unique_headers = list(set(headers))

# %%
unique_headers
# Out:
# ['PA AND LATERAL HISTORY:',
#  'PORTABLE CHEST RADIOGRAPH DATED COMPARISON:',
#  'PA AND LATERAL CHEST FILM AT INDICATION:',
#  'FINAL ADDENDUM HISTORY:',
#  'PORTABLE CHEST RADIOGRAPH WITH COMPARISON RADIOGRAPH FINDINGS:',
#  'PA AND LATERAL CHEST FROM ON HISTORY:',
#  'CHEST RADIOGRAPH DATED COMPARISON:',
#  'REASON FOR EXAMINATION:',
#  'PA AND LATERAL CHEST INDICATION:',
#  'CHEST ON AT HISTORY:',
#  'PA AND LATERAL CHEST RADIOGRAPH DATED WITH NO PRIOR RADIOGRAPHS FOR COMPARISON FINDINGS:',
#  'PA AND LATERAL CHEST RADIOGRAPHS INDICATION:',
#  'PORTABLE SUPINE CHEST DATED COMPARISON:',
#  'FINDINGS:',
#  'AP CHEST :',
#  'FINAL ADDENDUM ADDENDUM COMPARISON:',
#  'CHEST RADIOGRAPH:',
#  'SINGLE PORTABLE VIEW OF THE CHEST:',
#  'INDICATIONS:',
#  'PORTABLE CHEST :',
#  'CHEST PERFORMED ON COMPARISON:',
#  'PORTABLE UPRIGHT CHEST RADIOGRAPH CLINICAL HISTORY:',
#  'PA AND LATERAL CHEST FROM AT CLINICAL INDICATION:',
#  'FINAL ADDENDUM PLEASE NOTE:',
#  'SINGLE FRONTAL VIEW OF THE CHEST:',
#  'CHEST ON HISTORY:',
#  'PORTABLE CHEST WITH COMPARISON AND EARLIER RADIOGRAPHS AND CT DATING BETWEEN AND FINDINGS:',
#  'SINGLE AP VIEW OF THE CHEST INDICATION:',
#  'AP CHEST MIDNIGHT HISTORY:',
#  'PORTABLE CHEST RADIOGRAPH COMPARISON STUDY:',
#  'PORTABLE CHEST REASON FOR EXAM:',
#  'TECHNIQUE:',
#  'PA AND LATERAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'SINGLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'AP AND LATERAL CHEST OF COMPARISON:',
#  'CEHST RADIOGRAPH INDICATION:',
#  'A PORTABLE AP CHEST FILM AT INDICATION:',
#  'TYPE OF EXAMINATION:',
#  'CHEST RADIOGRAPHS:',
#  'CHEST SINGLE VIEW:',
#  'CHEST RADIOGRAPH NDICATION:',
#  'CHEST RADIOGRAPH REASON FOR EXAM:',
#  'ADDENDUM:',
#  'PA AND LATERAL CHEST RADIOGRAPHS COMPARISON:',
#  'FINAL ADDENDUM ADDENDUM :',
#  'CHEST RADIOGRAPH CLINICAL INDICATION:',
#  'RADIOGRAPH INDICATION:',
#  'CHEST RADIOGRAPHS HISTORY:',
#  'PORTABLE UPRIGHT CHEST DATED COMPARISON:',
#  'CHEST FRONTAL AND LATERAL VIEWS CLINICAL INFORMATION:',
#  'CHEST PORTABLE PLAIN FILM AT CLINICAL INDICATION:',
#  'CHEST RADIOGRAPH OF COMPARISON:',
#  'RADIOGRAPHS HISTORY:',
#  'CHESTS RADIOGRAPH INDICATION:',
#  'SINGLE PORTABLE VIEW REASON FOR EXAM:',
#  'CHESET RADIOGRAPH INDICATION:',
#  'FINAL ADDENDUM ADDENDUM CORRECTION:',
#  'CHEST CT TWO VIEWS:',
#  'PORTABLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'CHEST ULTRASOUND INDICATION:',
#  'PA AND LATERAL CHEST FILM CLINICAL INDICATION:',
#  'AP CHEST INDICATION:',
#  'PREOP CHEST RADIOGRAPH INDICATION:',
#  'AP CHEST ON :',
#  'TYPE OF THE EXAMINATION:',
#  'CLINICAL HISTORY:',
#  'SINGLE AP PORTABLE VIEW OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE SUPINE CHEST COMPARISON:',
#  'CHEST PORTABLE VIEW:',
#  'FINAL ADDENDUM ADDENDUM IMPRESSION:',
#  'CHEST TWO VIEWS:',
#  'PORTABLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'COMPARISON WITH A PRIOR STUDY FROM TODAY CLINICAL HISTORY:',
#  'SINGLE PORTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE AP CHEST FILM AT CLINICAL INDICATION:',
#  'CHEST REASON FOR EXAM:',
#  'CHEST RADIOGRAPHS COMPARISON:',
#  'CHEST AT INDICATION:',
#  'FRONTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE AP CHEST:',
#  'WITH COMPARISON STUDY OF ONE DAY EARLIER FINDINGS:',
#  'PORTABLE CHEST RADIOGRAPH ON COMPARISON:',
#  'PORTABLE CHEST:',
#  'PA AND LATERAL CHEST FILM AT CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST RADIOGRAPH :',
#  'PA AND LATERAL CHEST HISTORY:',
#  'PA AND LATERAL CHEST RADIOGRAPH COMPARISON:',
#  'TRACHEOSTOMY ON HISTORY:',
#  'PA AND LATERAL CHEST FROM CLINICAL INDICATION:',
#  'PORTAL FRONTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'AP PORTABLE CHEST COMPARISON:',
#  'PA AND LATERAL CHEST OF :',
#  'PORTABLE RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'PORTABLE CHEST WITH NO COMPARISON FINDINGS:',
#  'WITH COMPARISON RADIOGRAPH FINDINGS:',
#  'IMPRESSION:',
#  'PA AND LEFT LATERAL CHEST FILM AT CLINICAL INDICATION:',
#  'SINGLE PORTABLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'PA AND LATERAL VIEWS OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE CHEST WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DATE FINDINGS:',
#  'CHEST RADIOGRAPH AND EKG INDICATION:',
#  'CHEST RADIOGRAPHS CHEST RADIOGRAPHS HISTORY:',
#  'PORTABLE CHEST RADIOGRAPH HISTORY:',
#  'PA AND LATERAL CHEST RADIOGRAPHS OF COMPARISON:',
#  'RADIOGRAPHS OF THE CHEST HISTORY:',
#  'PORTABLE CHEST WITH COMPARISON RADIOGRAPH FINDINGS:',
#  'PELVIS RADIOGRAPH PERFORMED ON COMPARISON:',
#  'CHEST RADIOGRAPH FINDINGS:',
#  'PORTABLE CHEST WITH COMPARISON STUDY OF ONE DAY EARLIER FINDINGS:',
#  'CXR PORTABLE FILM HISTORY:',
#  'FRONTAL VIEW OF THE CHEST:',
#  'FINAL ADDENDUM ADDENDUM THIS REPORT SUPERSEDES THE EARLIER REPORT FOR THE STUDY OF AT HOURS:',
#  'PORTABLE CHEST FILM CLINICAL INDICATION:',
#  'CHEST RADIOGRAPH CLINICAL HISTORY:',
#  'PORTABLE UPRIGHT CHEST RADIOGRAPH OF COMPARISON:',
#  'COMPARISON:',
#  'CHEST RADIOGRAPHS CLINICAL HISTORY:',
#  'PORTABLE CHEST HISTORY:',
#  'PA AND LATERAL CHEST RADIOGRAPHS :',
#  'PORTABLE CHEST WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:',
#  'CHEST RADIOGRAPH EXAMINATION DATED COMPARISON:',
#  'SINGLE AP PORTABLE CHEST RADIOGRAPH DATED COMPARISON:',
#  'SINGLE FRONTAL VIEW OF CHEST REASON FOR EXAM:',
#  'PORTABLE AP CHEST FILM CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST EXAM OF COMPARISON:',
#  'INDICATION:',
#  'FRONTAL VIEWS OF THE CHEST REASON FOR EXAM:',
#  'PA AND LATERAL CHEST WITH COMPARISON RADIOGRAPH FINDINGS:',
#  'STUDY PA AND LATERAL CHEST RADIOGRAPH INDICATION:',
#  'SINGLE FRONTAL VIEWS OF THE CHEST REASON FOR EXAM:',
#  'AP AND LATERAL RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST RADIOGRAPH OF :',
#  'PA AND LATERAL CHEST :',
#  'FINAL ADDENDUM ADDENDUM IMPRESSION IN:',
#  'PREOP  COMPARISON:',
#  'SUPINE PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:',
#  'PA AND LATERAL CHEST FILM ON AT CLINICAL INDICATION:',
#  'PORTABLE CHEST WITH NO PRIOR RADIOGRAPHS FOR COMPARISON FINDINGS:',
#  'SEPSIS CHEST:',
#  'PA AND LATERAL COMPARISON:',
#  'PORTABLE CHEST COMPARISON STUDY:',
#  'CHEST RADIOGRAPH IMPRESSION:',
#  'PORTABLE CHEST DATED FINDINGS:',
#  'PA AND LATERAL CHEST RADIOGRAPH OF WITH NO PRIOR STUDIES FOR COMPARISON FINDINGS:',
#  'PORTABLE AP CHEST FILMS AT CLINICAL INDICATION:',
#  'WET READ:',
#  'CHEST RADIOGRAPH FROM HISTORY:',
#  'AP AND LATERAL CHEST ON HISTORY:',
#  'FINAL ADDENDUM ADDENDUM:',
#  'PORTABLE AP CHEST ON AT CLINICAL INDICATION:',
#  'CHEST RADIOGRAPHS IMPRESSION:',
#  'SINGLE VIEW  COMPARISON:',
#  'SINGLE PORTABLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'PORTABLE CHEST WITH COMPARISON STUDY OF EARLIER THE SAME DAY FINDINGS:',
#  'SUPINE PORTABLE CHEST COMPARISON:',
#  'CHEST RADIOGRAPHS INDICATIONS:',
#  'CHEST ON CHEST HISTORY:',
#  'PORTABLE CHEST FROM AT CLINICAL INDICATION:',
#  'PATIENT HISTORY:',
#  'CHEST TWO VIEWS :',
#  'AP CHEST:',
#  'PA AND LATERAL CHEST FILMS CLINICAL INDICATION:',
#  'CHEST PORTABLE AP INDICATION:',
#  'CHEST RADIOGRAPH COMPARISON:',
#  'PA AND LATERAL CHEST OF WITH COMPARISON FINDINGS:',
#  'CHEST RADIOGRAPH PERFORMED PORTABLY ON COMPARISON:',
#  'WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DATE FINDINGS:',
#  'PORTABLE CHEST ON HISTORY:',
#  'CHEAT RADIOGRAPH INDICATION:',
#  'PORTABLE VIEW OF THE CHEST REASON FOR EXAM:',
#  'PA AND LATERAL CHEST OF COMPARISON:',
#  'CHEST PA AND LATERAL INDICATION:',
#  'CXR TWO IMAGES HISTORY:',
#  'PA AND LATERAL CHEST FROM HISTORY:',
#  'PORTABLE UPRIGHT CHEST COMPARISON:',
#  'TYPE OF EXAM:',
#  'CHEST:',
#  'CHEST TWO VIEWS HISTORY:',
#  'CLINICAL INDICATION:',
#  'EXAM:',
#  'PA AND LATERAL RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'PORTABLE CHEST DATED COMPARISON:',
#  'PORTABLE AP CHEST INDICATION:',
#  'SERIES OF RADIOGRAPHS OBTAINED FOR ASSESSMENT OF NASOGASTRIC TUBE PLACEMENT COMPARISON:',
#  'CHEST RADIOGRAPHL INDICATION:',
#  'PORTABLE AP CHEST FILM AT INDICATION:',
#  'CHEST AND RIBS HISTORY:',
#  'FINAL ADDENDUM ADDENDUM HISTORY:',
#  'FINAL ADDENDUM COMPARISON:',
#  'CHEST SINGLE VIEW ON HISTORY:',
#  'CHEST RADIOGRAPH PERFORMED COMPARISON:',
#  'AT COMPARISON:',
#  'PORTABLE AP CHEST RADIOGRAPH INDICATION:',
#  'WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:',
#  'SUPINE CHEST RADIOGRAPH HISTORY:',
#  'CHEST PORTABLE AT INDICATION:',
#  'SINGLE VIEW OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE CHEST RADIOGRAPH COMPARISON:',
#  'PA AND LATERAL CHEST CLINICAL HISTORY:',
#  'PORTABLE UPRIGHT CHEST OF COMPARISON:',
#  'DATE:',
#  'PA AND LATERAL CHEST DATED COMPARISON:',
#  'RADIOGRAPHS OF THE CHEST AND RIBS HISTORY:',
#  'CHEST RADIOGRAPH TECHNIQUE:',
#  'SINGLE PORTABLE VIEW OF THE CHEST REASON FOR EXAM:',
#  'PORTABLE  COMPARISON:',
#  'A PORTABLE CHEST FILM AT CLINICAL INDICATION:',
#  'SINGLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:',
#  'AP CHEST NOON ON HISTORY:',
#  'PA CHEST RADIOGRAPH INDICATION:',
#  'PA AND LATERAL CHEST ON CLINICAL HISTORY:',
#  'REASON FOR INDICATION:',
#  'PORTABLE SUPINE CHEST OF COMPARISON:',
#  'PA LATERAL VIEWS OF THE CHEST:',
#  'PA AND LATERAL CHEST AT HOURS HISTORY:',
#  'PERFORMED ON COMPARISON:',
#  'FINAL ADDENDUM ADDENDUM ORIGINAL DICTATION WAS NOT COMPLETELY TRANSCRIBED AND SHOULD READ AS FOLLOWS:',
#  'CLINICAL INFORMATION:',
#  'AP AND LATERAL CHEST RADIOGRAPH DATED COMPARISON:',
#  'TIME:',
#  'PA AND LATERAL RADIOGRAPHS OF THE CHEST CLINICAL INDICATION:',
#  'PORTABLE CHEST RADIOGRAPH OF COMPARISON:',
#  'COMPARED TO PREVIOUS STUDY OF EARLIER THE SAME DAY FINDINGS:',
#  'PORTABLE AP CHEST FROM AT :',
#  'CHEST PORTABLE AT CLINICAL INDICATION:',
#  'PORTABLE AP CHEST FILM ON AT CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH OF FINDINGS:',
#  'SINGLE FRONTAL AND LATERAL VIEW OF THE CHEST REASON FOR EXAM:',
#  'PA AND LATERAL RADIOGRAPH OF THE CHEST:',
#  'CHEST AND PELVIS FILMS:',
#  'PA AND LATERAL CHEST WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:',
#  'CHEST RADIOGRAPH HISTORY:',
#  'PA AND LATERAL ON HISTORY:',
#  'PORTABLE RADIOGRAPHS COMPARISON:',
#  'PORTABLE CHEST RADIOGRAPH FROM HISTORY:',
#  'FINAL ADDENDUM ADDENDUM CHEST RADIOGRAPHS HISTORY:',
#  'PA AND LATERAL CHEST WITH COMPARISON RADIOGRAPHS OF ONE DAY EARLIER FINDINGS:',
#  'PORTABLE CHEST FILM AT INDICATION:',
#  'PORTABLE AP CHEST FILM UPRIGHT CLINICAL INDICATION:',
#  'DATE OF EXAM:',
#  'PA AND LATERAL CHEST:',
#  'CHEST PA AND LATERAL HISTORY:',
#  'REASON FOR THE EXAM:',
#  'CHEST TWO VIEWS ON HISTORY:',
#  'FINAL ADDENDUM ADDENDUM INDICATION:',
#  'PA AND LATERAL CHEST COMPARISON:',
#  'CXR SINGLE PORTABLE FILM HISTORY:',
#  'AP AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:',
#  'PORTABLE CHEST COMPARISON:',
#  'CHEST PORTABLE INDICATION:',
#  'FINAL ADDENDUM INDICATION:',
#  'CHEST RADIOGRAPH INDICATION:',
#  'PORTABLE CHEST RADIOGRAPH WITH COMPARISON TO RADIOGRAPH OF ONE DAY EARLIER FINDINGS:',
#  'PORTABLE AP CHEST CLINICAL INDICATION:',
#  'SERIES OF PORTABLE CHEST RADIOGRAPHS OF COMPARISON:',
#  'AP  COMPARISON:',
#  'TWO VIEW CHEST OF COMPARISON:',
#  'PORTABLE CHEST FILM AT CLINICAL INDICATION:',
#  'WET :',
#  'PORTABLE CHEST ON AT CLINICAL INDICATION:',
#  'CHEST AP:',
#  'CHEST INDICATION:',
#  'FINAL ADDENDUM ADDENDUM CHEST RADIOGRAPHS INDICATION:',
#  'FRONTAL AND LATERAL VIEWS OF THE CHEST REASON FOR EXAM:',
#  'PA AND LATERAL CHEST RADIOGRAPHS DATED COMPARISON:',
#  'CHEST PORTABLE RADIOGRAPH CLINICAL HISTORY:',
#  'HISTORY:',
#  'PA AND LATERAL CHEST ON :',
#  'AP AND LATERAL VIEWS OF THE CHEST REASON FOR EXAM:',
#  'WITH COMPARISON RADIOGRAPH OF FINDINGS:',
#  'PORTABLE CHEST ON COMPARISON:',
#  'FINAL ADDENDUM TYPE OF EXAMINATION:',
#  'CHEST RADIOGRAPHS INDICATION:',
#  'AP PORTABLE CHEST RADIOGRAPH COMPARISON EXAM:',
#  'CHEST FILM AT CLINICAL INDICATION:',
#  'PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:',
#  'PA AND LATERAL VIEWS OF THE CHEST:',
#  'PA AND LATERAL CHEST RADIOGRAPH DATED COMPARISON:',
#  'PA AND LATERAL CHEST RADIOGRAPH OF COMPARISON:',
#  'STUDY:',
#  'EXAMINATION:',
#  'FINAL ADDENDUM CHEST RADIOGRAPH ADDENDUM:',
#  'REASON FOR EXAM:',
#  'COMPARISON STUDY:',
#  'PA AND LATERAL CHEST RADIOGRAPH CLINICAL INDICATION:',
#  'AP CHEST HISTORY:',
#  'CHEST CLINICAL HISTORY:',
#  'PA AND LATERAL CHEST IMPRESSION:',
#  'CHEST HISTORY:',
#  'PA AND LATERAL CHEST RADIOGRAPH INDICATION:',
#  'PA AND LATERAL CHEST RADIOGRAPH OF FINDINGS:',
#  'PORTABLE AP CHEST FROM AT CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST OF WITH COMPARISON STUDY OF EARLIER THE SAME DATE FINDINGS:',
#  'AP CHEST COMPARED TO :',
#  'HISTORY :',
#  'FINAL ADDENDUM NOTE:',
#  'FINAL ADDENDUM CHEST PA AND LATERAL AMENDMENT:',
#  'CHEST RADIOGRAPHS PERFORMED ON COMPARISON:',
#  'CHEST OF HISTORY:',
#  'CHEST RADIOGRAPH INDICATIONS:',
#  'CHEST TWO VIEWS INDICATION:',
#  'AP CHEST ON HISTORY:',
#  'PA AND LATERAL CHEST CLINICAL INDICATION:',
#  'PA AND LATERAL CHEST ON HISTORY:',
#  'AP UPRIGHT AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:',
#  'PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH FINDINGS:']

# %%
len(unique_headers)
# Out:
# 306

# %% [markdown]
# # extract headers for each row

# %%
df
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...
# ...                                                   ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...
# 227832  COMPARISON: radiograph. FINDINGS: There has be...
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834  INDICATION: -year-old female intubated for hea...
#
# [227835 rows x 5 columns]

# %%
df2=df

# %%
# expression pattern to match headers
header_pattern = re.compile(r'([A-Z][A-Z ]+:)')
headers = []

for content in df['cleaned_content']:
    # find all matches of header_pattern
    matches = header_pattern.findall(content)
    if matches:
        # if found, append 
        headers.append(matches)
    else:
        # if no found, append an empty list
        headers.append([])
df['headers'] = headers

# %%
df
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content  \
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...
# ...                                                   ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...
# 227832  COMPARISON: radiograph. FINDINGS: There has be...
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834  INDICATION: -year-old female intubated for hea...
#
#                                                   headers
# 0       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 1       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 2       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# 3       [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 4       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# ...                                                   ...
# 227830  [INDICATION:, COMPARISON:, FINDINGS:, CONCLUSI...
# 227831  [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 227832                           [COMPARISON:, FINDINGS:]
# 227833  [COMPARISON:, CLINICAL HISTORY:, FINDINGS:, IM...
# 227834  [INDICATION:, COMPARISON:, TECHNIQUE:, FINDING...
#
# [227835 rows x 6 columns]

# %% [markdown]
# # Add headers columns

# %%
header_columns = {}
for header in unique_headers:
    header_columns[header] = []

# Extract and populate data for each header column
for index, row in df2.iterrows():
    for header in unique_headers:
        data = ""
        header_columns[header].append(data)

new_df = pd.DataFrame(header_columns)
df = pd.concat([df, new_df], axis=1)

# %%
df
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content  \
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...
# ...                                                   ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...
# 227832  COMPARISON: radiograph. FINDINGS: There has be...
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834  INDICATION: -year-old female intubated for hea...
#
#                                                   headers  \
# 0       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 1       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 2       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# 3       [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 4       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# ...                                                   ...
# 227830  [INDICATION:, COMPARISON:, FINDINGS:, CONCLUSI...
# 227831  [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 227832                           [COMPARISON:, FINDINGS:]
# 227833  [COMPARISON:, CLINICAL HISTORY:, FINDINGS:, IM...
# 227834  [INDICATION:, COMPARISON:, TECHNIQUE:, FINDING...
#
#        PA AND LATERAL HISTORY: PORTABLE CHEST RADIOGRAPH DATED COMPARISON:  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                                         ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST FILM AT INDICATION: FINAL ADDENDUM HISTORY:  ...  \
# 0                                                                        ...
# 1                                                                        ...
# 2                                                                        ...
# 3                                                                        ...
# 4                                                                        ...
# ...                                         ...                     ...  ...
# 227830                                                                   ...
# 227831                                                                   ...
# 227832                                                                   ...
# 227833                                                                   ...
# 227834                                                                   ...
#
#        FINAL ADDENDUM CHEST PA AND LATERAL AMENDMENT:  \
# 0
# 1
# 2
# 3
# 4
# ...                                               ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        CHEST RADIOGRAPHS PERFORMED ON COMPARISON: CHEST OF HISTORY:  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...               ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        CHEST RADIOGRAPH INDICATIONS: CHEST TWO VIEWS INDICATION:  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...                         ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        AP CHEST ON HISTORY: PA AND LATERAL CHEST CLINICAL INDICATION:  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                                       ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST ON HISTORY:  \
# 0
# 1
# 2
# 3
# 4
# ...                                 ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        AP UPRIGHT AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH FINDINGS:
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
# [227835 rows x 312 columns]

# %% [markdown]
# # add true if header is in the file (this bit runs forever! only to double check the following code works well)

# %%
for headers in df['headers']:
    for header in headers:
        if header in df.columns:
            df[header] = df[header].fillna("False")
            df.loc[df[header].isna(), header] = "True"

# %%
df

# %% [markdown]
# # count how often each header appears

# %%
from collections import Counter

# %%
all_headers = ",".join(df["headers"].astype(str).tolist())
all_headers = all_headers.replace("[", "").replace("]", "")
all_names = [name.strip() for name in all_headers.split(",")]

# Count the occurrences of each name
name_counts = Counter(all_names)

for name, count in sorted(name_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{name}: {count}")
# Out:
# 'IMPRESSION:': 184726
# 'COMPARISON:': 158784
# 'FINDINGS:': 148917
# 'INDICATION:': 140777
# 'EXAMINATION:': 93950
# 'TECHNIQUE:': 76669
# 'HISTORY:': 39474
# 'WET READ:': 17557
# 'CHEST RADIOGRAPH INDICATION:': 10082
# 'CLINICAL HISTORY:': 7061
# 'REASON FOR EXAMINATION:': 5836
# 'NOTIFICATION:': 5731
# 'CLINICAL INFORMATION:': 4016
# 'EXAM:': 3906
# 'STUDY:': 2780
# 'SINGLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 2657
# 'CHEST RADIOGRAPHS HISTORY:': 2299
# 'PNA TECHNIQUE:': 2129
# 'CONCLUSION:': 1800
# 'TWO VIEWS:': 1737
# 'TYPE OF EXAMINATION:': 1675
# 'CLINICAL INDICATION:': 1465
# 'ON HISTORY:': 1338
# 'PA AND LATERAL VIEWS OF THE CHEST REASON FOR EXAM:': 1294
# 'CHEST RADIOGRAPHS INDICATION:': 1079
# 'PNA COMPARISON:': 1047
# 'PA AND LATERAL VIEWS OF THE CHEST:': 914
# 'PNA IMPRESSION:': 881
# 'CHEST RADIOGRAPH HISTORY:': 835
# 'CHEST ON HISTORY:': 610
# 'FRONTAL AND LATERAL CHEST RADIOGRAPHS:': 603
# 'RAY INDICATION:': 541
# 'PA AND LATERAL CHEST RADIOGRAPHS:': 529
# 'CT FINDINGS:': 509
# 'PA AND LATERAL CHEST ON HISTORY:': 501
# 'PORTABLE CHEST:': 485
# 'PORTABLE CHEST COMPARISON:': 449
# 'PTX TECHNIQUE:': 419
# 'PTX IMPRESSION:': 409
# 'PA AND LATERAL CHEST RADIOGRAPH:': 393
# 'REASON FOR EXAM:': 351
# 'REFERENCE EXAM:': 350
# 'PTX COMPARISON:': 346
# 'CHEST RADIOGRAPH TECHNIQUE:': 330
# 'PA AND LATERAL:': 327
# 'TWO VIEWS OF THE CHEST:': 321
# 'FRONTAL AND LATERAL VIEWS OF THE CHEST:': 320
# 'CHF TECHNIQUE:': 310
# 'PATIENT HISTORY:': 251
# 'PORTABLE AP CHEST RADIOGRAPH:': 240
# 'FRONTAL CHEST RADIOGRAPH:': 236
# 'CHEST:': 206
# 'DX CHEST PORTABLE PICC LINE PLACEMENT INDICATION:': 182
# 'PA AND LATERAL CHEST OF COMPARISON:': 178
# 'PORTABLE FRONTAL CHEST RADIOGRAPH:': 173
# 'AP COMPARISON:': 171
# 'CHEST PA AND LATERAL INDICATION:': 167
# 'FINAL ADDENDUM ADDENDUM:': 167
# 'PA AND LATERAL CHEST RADIOGRAPHS INDICATION:': 163
# 'COMPARISON EXAM:': 162
# 'REPORT:': 162
# 'RAY OF COMPARISON:': 147
# 'EXAM INDICATION:': 146
# 'PA AND LATERAL CHEST HISTORY:': 144
# 'CHEST RADIOGRAPH:': 137
# 'CHF COMPARISON:': 135
# 'ETT TECHNIQUE:': 135
# 'AP:': 116
# 'CTA FINDINGS:': 116
# 'CHEST HISTORY:': 114
# 'ETT IMPRESSION:': 110
# 'PA AND LATERAL CHEST COMPARISON:': 109
# 'CXR:': 108
# 'DATE:': 108
# 'PORTABLE CHEST FILM AT CLINICAL INDICATION:': 99
# 'ONE VIEW OF THE CHEST:': 98
# 'CXR IMPRESSION:': 97
# 'UPRIGHT AP VIEW OF THE CHEST:': 96
# 'UPRIGHT AP AND LATERAL VIEWS OF THE CHEST:': 94
# 'CHF IMPRESSION:': 92
# 'CXR TECHNIQUE:': 90
# 'PORTABLE AP CHEST FILM AT CLINICAL INDICATION:': 90
# 'CHEST TWO VIEWS:': 89
# 'COMMENT:': 88
# 'EXAMS INDICATION:': 87
# 'FINDINGS AND IMPRESSION:': 87
# 'TB TECHNIQUE:': 86
# 'NGT IMPRESSION:': 84
# 'SOB TECHNIQUE:': 83
# 'SINGLE AP PORTABLE VIEW:': 83
# 'SOB COMPARISON:': 83
# 'CXR COMPARISON:': 79
# 'ETT COMPARISON:': 79
# 'RAY COMPARISON:': 74
# 'FRONTAL AND LATERAL CHEST RADIOGRAPH:': 74
# 'AM IMPRESSION:': 72
# 'AP AND LATERAL CHEST RADIOGRAPHS:': 72
# 'RECOMMENDATIONS:': 72
# 'CT IMPRESSION:': 72
# 'PA AND LATERAL CHEST FILM AT CLINICAL INDICATION:': 69
# 'PORTABLE CHEST RADIOGRAPH INDICATION:': 68
# 'NOTE:': 67
# 'FRONTAL AND LATERAL CHEST:': 66
# 'TB IMPRESSION:': 65
# 'NGT TECHNIQUE:': 65
# 'CHEST RADIOGRAPH COMPARISON:': 64
# 'PM IMPRESSION:': 64
# 'CHEST AP:': 59
# 'AP AND LATERAL VIEWS OF THE CHEST:': 58
# 'PA AND LATERAL CHEST:': 58
# : 57
# 'NGT COMPARISON:': 55
# 'PA AND LATERAL RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 55
# 'AM TECHNIQUE:': 54
# 'AT CLINICAL INDICATION:': 50
# 'AM COMPARISON:': 48
# 'COMPARISON FILM:': 48
# 'ABNORMALITY IMPRESSION:': 46
# 'COMMENTS:': 45
# 'ICH TECHNIQUE:': 44
# 'SINGLE FRONTAL VIEW OF THE CHEST:': 42
# 'PORTABLE UPRIGHT AP VIEW OF THE CHEST:': 42
# 'ACS TECHNIQUE:': 40
# 'SOB IMPRESSION:': 40
# 'SINGLE AP PORTABLE VIEW OF THE CHEST REASON FOR EXAM:': 40
# 'PM COMPARISON:': 39
# 'RAY DATED COMPARISON:': 39
# 'TB COMPARISON:': 38
# 'QUESTIONS TO BE ANSWERED:': 38
# 'PORTABLE CHEST RADIOGRAPH DATED COMPARISON:': 38
# 'AP AND LATERAL:': 36
# 'PORT INDICATION:': 36
# 'CP TECHNIQUE:': 36
# 'PORTABLE  COMPARISON:': 36
# 'CT:': 36
# 'O PNA TECHNIQUE:': 35
# 'TWO VIEWS HISTORY:': 35
# 'SINGLE PORTABLE VIEW OF THE CHEST REASON FOR EXAM:': 34
# 'O PNEUMONIA IMPRESSION:': 34
# 'PICC TECHNIQUE:': 33
# 'AP UPRIGHT:': 33
# 'MD CC:': 33
# 'COPD TECHNIQUE:': 32
# 'CXR INDICATION:': 32
# 'CHEST TWO VIEWS ON HISTORY:': 31
# 'RECOMMENDATION:': 30
# 'CP COMPARISON:': 30
# 'PE TECHNIQUE:': 30
# 'ERECT FRONTAL CHEST RADIOGRAPH:': 29
# 'PM TECHNIQUE:': 28
# 'PM PFI:': 28
# 'CHEST AP COMPARISON:': 28
# 'SUPINE AP VIEW OF THE CHEST:': 28
# 'PICC COMPARISON:': 28
# 'OGT TECHNIQUE:': 28
# 'PORTABLE CHEST DATED COMPARISON:': 28
# 'FRONTAL UPRIGHT PORTABLE CHEST:': 27
# 'PORTABLE CHEST RADIOGRAPH COMPARISON:': 26
# 'PROCEDURE:': 26
# 'PE COMPARISON:': 26
# 'PNA PNA IMPRESSION:': 26
# 'AP AND LATERAL CHEST RADIOGRAPH:': 26
# 'O ABNORMALITY IMPRESSION:': 25
# 'SINGLE AP PORTABLE VIEW COMPARISON:': 25
# 'ARDS IMPRESSION:': 25
# 'OGT IMPRESSION:': 25
# 'CXR FINDINGS:': 24
# 'PORTABLE FRONTAL VIEW OF THE CHEST:': 24
# 'SVC IMPRESSION:': 24
# 'AP UPRIGHT AND LATERAL:': 24
# 'UPRIGHT PORTABLE CHEST:': 23
# 'PORTABLE CHEST RADIOGRAPH:': 23
# 'PORTABLE UPRIGHT RADIOGRAPH OF THE CHEST:': 22
# 'PA AND LATERAL CHEST RADIOGRAPH COMPARISON:': 22
# 'ARDS TECHNIQUE:': 21
# 'PORTABLE CHEST RADIOGRAPH OF COMPARISON:': 21
# 'PNA EXAMINATION:': 20
# 'SINGLE FRONTAL PORTABLE VIEW OF THE CHEST:': 20
# 'OGT COMPARISON:': 20
# 'PA AND LATERAL CHEST RADIOGRAPH DATED COMPARISON:': 19
# 'AT HOURS HISTORY:': 19
# 'COPD COMPARISON:': 19
# 'AM ON HISTORY:': 19
# 'SINGLE AP VIEW OF THE CHEST:': 19
# 'PA AND LATERAL CHEST RADIOGRAPH INDICATION:': 19
# 'ON CLINICAL HISTORY:': 18
# 'COUGH IMPRESSION:': 18
# 'PORTABLE SUPINE CHEST RADIOGRAPH:': 18
# 'PM  EXAMINATION:': 18
# 'AMS COMPARISON:': 18
# 'ARDS COMPARISON:': 18
# 'CHEST PORTABLE:': 17
# 'PA AND LATERAL COMPARISON:': 17
# 'PICC IMPRESSION:': 17
# 'PM ON HISTORY:': 17
# 'PA COMPARISON:': 17
# 'PA AND LATERAL CHEST RADIOGRAPHS COMPARISON:': 16
# 'RAY REPORT INDICATION:': 16
# 'SINGLE PORTABLE FRONTAL VIEW OF THE CHEST:': 16
# 'AM FINDINGS:': 16
# 'AP CHEST HISTORY:': 16
# 'PACU COMPARISON:': 15
# 'O PNEUMONIA COMPARISON:': 15
# 'CT TECHNIQUE:': 15
# 'CT :': 15
# 'O PNA COMPARISON:': 15
# 'CHEST RADIOGRAPH FROM HISTORY:': 15
# 'CHEST RADIOGRAPH FINDINGS:': 15
# 'AM INDICATION:': 15
# 'NONE FINDINGS:': 15
# 'CVL TECHNIQUE:': 15
# 'CC:': 15
# 'CHEST PORTABLE INDICATION:': 15
# 'CHEST COMPARISON:': 15
# 'DOE COMPARISON:': 15
# 'SINGLE AP VIEW:': 14
# 'PACU TECHNIQUE:': 14
# 'FRONTAL SUPINE PORTABLE CHEST:': 14
# 'O CHF TECHNIQUE:': 14
# 'PA AND LATERAL CHEST RADIOGRAPH OF COMPARISON:': 14
# 'NA TECHNIQUE:': 14
# 'VIEW PICC LINE PLACEMENT INDICATION:': 14
# 'ADDENDUM:': 14
# 'A  EXAMINATION:': 14
# 'CHEST RADIOGRAPH PERFORMED COMPARISON:': 14
# 'THROUGH IMPRESSION:': 14
# 'CT NOTIFICATION:': 14
# 'CABG IMPRESSION:': 14
# 'AP AND LATERAL CHEST RADIOGRAPHS INDICATION:': 13
# 'NSR  EXAMINATION:': 13
# 'AP CHEST:': 13
# 'TAVR IMPRESSION:': 13
# 'O PTX IMPRESSION:': 13
# 'INDICATIONS:': 13
# 'PNA PNA COMPARISON:': 13
# 'CHEST COMPARISON FILM:': 13
# 'R PTX COMPARISON:': 13
# 'PE IMPRESSION:': 13
# 'PNA FINDINGS:': 12
# 'NA COMPARISON:': 12
# 'PA AND LATERAL CHEST FILM CLINICAL INDICATION:': 12
# 'PORTABLE AP CHEST RADIOGRAPH INDICATION:': 12
# 'PA AND LATERAL VIEWS:': 12
# 'UPRIGHT PORTABLE RADIOGRAPH OF THE CHEST:': 12
# 'PA AND LATERAL CHEST FILM AT INDICATION:': 12
# 'IABP COMPARISON:': 12
# 'FRONTAL PORTABLE CHEST:': 12
# 'CHEST SINGLE VIEW COMPARISON:': 12
# 'P FINDINGS:': 12
# 'ERECT:': 11
# 'FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 11
# 'PORTABLE AP UPRIGHT CHEST RADIOGRAPH:': 11
# 'PCP :': 11
# 'TWO VIEWS INDICATION:': 11
# 'DVT TECHNIQUE:': 11
# 'CHEST INDICATION:': 11
# 'PORTABLE SUPINE RADIOGRAPH OF THE CHEST:': 11
# 'AMS TECHNIQUE:': 11
# 'ABNORMALITY COMPARISON:': 11
# 'WBC TECHNIQUE:': 11
# 'ERECT PORTABLE CHEST:': 11
# 'UPRIGHT CHEST RADIOGRAPH:': 11
# 'CPD TECHNIQUE:': 11
# 'CHEST RADIOGRAPHS IMPRESSION:': 11
# 'AM PFI:': 11
# 'CVL IMPRESSION:': 10
# 'M HISTORY:': 10
# 'ILD COMPARISON:': 10
# 'PORTABLE UPRIGHT FRONTAL VIEW OF THE CHEST:': 10
# 'SINGLE AP VIEW COMPARISON:': 10
# 'DOE TECHNIQUE:': 10
# 'PA AND LATERAL CHEST ON :': 10
# 'SINGLE AP PORTABLE VIEW OF THE CHEST:': 10
# 'R PTX IMPRESSION:': 10
# 'COPD IMPRESSION:': 10
# 'R PTX TECHNIQUE:': 10
# 'NOTIFICATIONS:': 10
# 'PORTABLE CHEST HISTORY:': 10
# 'REFERENCE EXAMINATION:': 9
# 'PORTABLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 9
# 'TWO VIEWS COMPARISON:': 9
# 'PORTABLE AP CHEST FILM AT INDICATION:': 9
# 'PORTABLE AP CHEST INDICATION:': 9
# 'AP VIEW OF THE CHEST COMPARISON:': 9
# 'PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:': 9
# 'SUPINE PORTABLE CHEST RADIOGRAPH:': 9
# 'PORTABLE SUPINE FRONTAL VIEW OF THE CHEST:': 9
# 'PA AND LATERAL CHEST INDICATION:': 9
# 'WBC COMPARISON:': 9
# 'ACS COMPARISON:': 9
# 'PORTABLE SUPINE FRONTAL CHEST RADIOGRAPH:': 9
# 'VAP TECHNIQUE:': 9
# 'AM CLINICAL INDICATION:': 9
# 'PM FINDINGS:': 9
# 'PET CT FINDINGS:': 9
# 'TWO VIEWS ON HISTORY:': 9
# 'FRONTAL CHEST RADIOGRAPHS:': 9
# 'O ABNORMALITY COMPARISON:': 9
# 'FRONTAL VIEW OF THE CHEST:': 8
# 'PPD TECHNIQUE:': 8
# 'SINGLE PORTABLE VIEW OF THE CHEST:': 8
# 'PTX EXAMINATION:': 8
# 'CAP TECHNIQUE:': 8
# 'PORTABLE AP VIEW OF THE CHEST:': 8
# 'PORTABLE UPRIGHT CHEST RADIOGRAPH:': 8
# 'INFILTRATE IMPRESSION:': 8
# 'A  HISTORY:': 8
# 'PA AND LATERAL CHEST RADIOGRAPHS OF COMPARISON:': 8
# 'IABP IMPRESSION:': 8
# 'OSH COMPARISON:': 8
# 'RADIOGRAPHS FROM IMPRESSION:': 8
# 'PA AND LATERAL CHEST :': 8
# 'PA AND LATERAL RADIOGRAPHS OF THE CHEST:': 8
# 'XR IMPRESSION:': 8
# 'VAP IMPRESSION:': 8
# 'CHEST AP COMPARISON FILM:': 8
# 'CABG TECHNIQUE:': 8
# 'RIJ TECHNIQUE:': 8
# 'FINDING:': 8
# 'ETT ETT IMPRESSION:': 8
# 'PNX IMPRESSION:': 8
# 'PLEASE TAKE AT :': 8
# 'AP VIEW OF THE CHEST:': 8
# 'WITH COMPARISON RADIOGRAPH FINDINGS:': 8
# 'PORTABLE AP CHEST FILM CLINICAL INDICATION:': 7
# 'COMPARISON STUDY:': 7
# 'A  STUDY:': 7
# 'OSH TECHNIQUE:': 7
# 'PTX FINDINGS:': 7
# 'MRI TECHNIQUE:': 7
# 'AVR IMPRESSION:': 7
# 'SINGLE PORTABLE AP CHEST RADIOGRAPH:': 7
# 'COUGH COMPARISON:': 7
# 'CP IMPRESSION:': 7
# 'ERECT CHEST RADIOGRAPH:': 7
# 'PA AND LATERAL CHEST RADIOGRAPHS DATED COMPARISON:': 7
# 'HOURS HISTORY:': 7
# 'PORTABLE CHEST INDICATION:': 7
# 'NO COMPARISON IMPRESSION:': 7
# 'RAY FROM FINDINGS:': 7
# 'CHEST ON AT HISTORY:': 7
# 'CABG COMPARISON:': 7
# 'WBC IMPRESSION:': 7
# 'AP PORTABLE CHEST RADIOGRAPH:': 7
# 'LLL COMPARISON:': 7
# 'P IMPRESSION:': 7
# 'ON IMPRESSION:': 7
# 'O PTX COMPARISON:': 7
# 'MAIN REPORT:': 7
# 'PNX TECHNIQUE:': 7
# 'LATERAL VIEWS OF THE CHEST:': 7
# 'SINGLE VIEW:': 7
# 'CHEST RADIOGRAPHS SINCE MOST RECENTLY IMPRESSION:': 7
# 'UPRIGHT AP CHEST RADIOGRAPH:': 7
# 'DATED COMPARISON:': 7
# 'DOE SOB TECHNIQUE:': 7
# 'NONE IMPRESSION:': 7
# 'SOB PNA TECHNIQUE:': 7
# 'PM PRELIMINARY REPORT:': 7
# 'SUPINE:': 7
# 'SINGLE PORTABLE AP VIEW OF THE CHEST:': 7
# 'AM HISTORY:': 6
# 'COMPARISON :': 6
# 'ILD IMPRESSION:': 6
# 'LINE PLACEMENT INDICATION:': 6
# 'CHEST RADIOGRAPHS CLINICAL HISTORY:': 6
# 'RLL IMPRESSION:': 6
# 'RADIOGRAPH INDICATION:': 6
# 'T IMPRESSION:': 6
# 'VAP COMPARISON:': 6
# 'PPM TECHNIQUE:': 6
# 'LLL IMPRESSION:': 6
# 'CHEST SINGLE VIEW:': 6
# 'DX CHEST WITH DECUB INDICATION:': 6
# 'LLL PNA TECHNIQUE:': 6
# 'MVC TECHNIQUE:': 6
# 'RADIOGRAPHS OF THE CHEST HISTORY:': 6
# 'NG TECHNIQUE:': 6
# 'ERECT PORTABLE FRONTAL CHEST RADIOGRAPH:': 6
# 'REASON FOR THE EXAM:': 6
# 'UPRIGHT FRONTAL CHEST RADIOGRAPH:': 6
# 'PA AND LATERAL CHEST DATED COMPARISON:': 6
# 'SUPINE PORTABLE CHEST:': 6
# 'HD IMPRESSION:': 6
# 'PA AND LAT CHEST RADIOGRAPH:': 6
# 'LAD TECHNIQUE:': 6
# 'UPRIGHT CHEST COMPARISON:': 6
# 'PTX PTX IMPRESSION:': 6
# 'RLL COMPARISON:': 6
# 'AP CHEST RADIOGRAPH:': 6
# 'ICH COMPARISON:': 6
# 'PORTABLE CHEST WITH COMPARISON RADIOGRAPH FINDINGS:': 6
# 'PACU IMPRESSION:': 6
# 'PORTABLE CHEST RADIOGRAPH HISTORY:': 6
# 'A  INDICATION:': 6
# 'A  SINGLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 6
# 'PORTABLE SUPINE AP CHEST RADIOGRAPH:': 6
# 'CHF CHF IMPRESSION:': 6
# 'O PNA IMPRESSION:': 6
# 'CHEST REASON FOR EXAM:': 6
# 'HF TECHNIQUE:': 6
# 'ICHCXR:': 6
# 'HF COMPARISON:': 6
# 'A  CLINICAL HISTORY:': 6
# 'WET :': 6
# 'FRONTAL PORTABLE CHEST RADIOGRAPH:': 6
# 'PORTABLE CHEST :': 6
# 'SOB SOB TECHNIQUE:': 6
# 'ON :': 6
# 'RAY HISTORY:': 6
# 'ICD IMPRESSION:': 5
# 'RAY FINDINGS:': 5
# 'UPRIGHT AP AND LATERAL VIEWS OF THE CHEST COMPARISON:': 5
# 'PORTABLE AP CHEST:': 5
# 'O PTX TECHNIQUE:': 5
# 'PORTABLE AP CHEST CLINICAL INDICATION:': 5
# 'PNEUMONIA IMPRESSION:': 5
# 'RLL PNA TECHNIQUE:': 5
# 'PORTABLE AP CHEST ON AT CLINICAL INDICATION:': 5
# 'IJ TECHNIQUE:': 5
# 'AVR COMPARISON:': 5
# 'PA AND LATERAL RADIOGRAPHS OF THE CHEST CLINICAL INDICATION:': 5
# 'AMS PNA TECHNIQUE:': 5
# 'CM TECHNIQUE:': 5
# 'L TECHNIQUE:': 5
# 'CTA IMPRESSION:': 5
# 'ICD TECHNIQUE:': 5
# 'AP CHEST ON HISTORY:': 5
# 'SOB SOB COMPARISON:': 5
# 'ETT ETT ETT IMPRESSION:': 5
# 'MVC COMPARISON:': 5
# 'UPRIGHT CHEST OF COMPARISON:': 5
# 'PA FINDINGS:': 5
# 'FB COMPARISON:': 5
# 'NGT NGT TECHNIQUE:': 5
# 'PORTABLE SUPINE CHEST OF COMPARISON:': 5
# 'NSR  INDICATION:': 5
# 'NA IMPRESSION:': 5
# 'CHF EXAMINATION:': 5
# 'CA TECHNIQUE:': 5
# 'CVL COMPARISON:': 5
# 'IABP TECHNIQUE:': 5
# 'FRONTAL AND LATERAL CHEST RADIOGRAPHS INDICATION:': 5
# 'PA AND LATERAL CHEST RADIOGRAPH CLINICAL INDICATION:': 5
# 'ICU TECHNIQUE:': 5
# 'PORTABLE AP FRONTAL CHEST RADIOGRAPH:': 5
# 'PORTABLE INDICATION:': 5
# 'ERECT CHEST FILM AT CLINICAL INDICATION:': 5
# 'COMPARISON STUDIES:': 5
# 'CHEST RADIOGRAPHS THROUGH IMPRESSION:': 5
# 'IMPRESSIONS:': 5
# 'J  CHEST RADIOGRAPH INDICATION:': 5
# 'L PTX IMPRESSION:': 5
# 'CT COMPARISON:': 5
# 'PORTABLE CHEST FROM AT CLINICAL INDICATION:': 5
# 'PM INDICATION:': 5
# 'PA AND LATERAL COMPARISON FILM:': 5
# 'PNM COMPARISON:': 5
# 'CHEST TWO VIEWS HISTORY:': 5
# 'PPD IMPRESSION:': 5
# 'CXR ABNORMALITIES IMPRESSION:': 5
# 'CHEST RADIOGRAPHS:': 5
# 'WITH COMPARISON FINDINGS:': 5
# 'ERECT AP CHEST RADIOGRAPH:': 5
# 'LLL TECHNIQUE:': 4
# 'LAD COMPARISON:': 4
# 'AP PORTABLE FRONTAL CHEST RADIOGRAPH:': 4
# 'XR COMPARISON:': 4
# 'ILD TECHNIQUE:': 4
# 'OSH CXR TECHNIQUE:': 4
# 'MRI FINDINGS:': 4
# 'ICD COMPARISON:': 4
# 'ETT ETT TECHNIQUE:': 4
# 'L COMPARISON:': 4
# 'DKA COMPARISON:': 4
# 'RUL COMPARISON:': 4
# 'WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:': 4
# 'AP SUPINE:': 4
# 'PNA PNA PNA IMPRESSION:': 4
# 'PORTABLE AP VIEW OF THE CHEST COMPARISON:': 4
# 'AP FINDINGS:': 4
# 'RUQ:': 4
# 'AP AND LATERAL COMPARISON:': 4
# 'RAY:': 4
# 'PNA PNA TECHNIQUE:': 4
# 'L PTX COMPARISON:': 4
# 'TAVR COMPARISON:': 4
# 'CAP COMPARISON:': 4
# 'IMPRESSION :': 4
# 'AP CHEST :': 4
# 'OR IMPRESSION:': 4
# 'PA AND LATERAL VIEWS OF CHEST:': 4
# 'NCHCT:': 4
# 'A  CHEST RADIOGRAPH INDICATION:': 4
# 'ETT ETT COMPARISON:': 4
# 'CA COMPARISON:': 4
# 'PA AND LATERAL CHEST FROM AT CLINICAL INDICATION:': 4
# 'CHF FINDINGS:': 4
# 'UPRIGHT CHEST DATED COMPARISON:': 4
# 'AP UPRIGHT AND LATERAL CHEST RADIOGRAPHS:': 4
# 'RVR TECHNIQUE:': 4
# 'PA AND LATERAL VIEW OF THE CHEST REASON FOR EXAM:': 4
# 'AP CHEST COMPARED TO :': 4
# 'SINGLE FRONTAL CHEST RADIOGRAPH COMPARISON:': 4
# 'UPRIGHT FRONTAL VIEW OF THE CHEST:': 4
# 'FINDINGS :': 4
# 'HIV TECHNIQUE:': 4
# 'IJ IMPRESSION:': 4
# 'CHEST RADIOGRAPHS THROUGH :': 4
# 'CHEST RADIOGRAPHS COMPARISON:': 4
# 'NSTEMI TECHNIQUE:': 4
# 'RIJ IMPRESSION:': 4
# 'TAVR TECHNIQUE:': 4
# 'PA INDICATION:': 4
# 'RLL TECHNIQUE:': 4
# 'O CHF COMPARISON:': 4
# 'ERECT COMPARISON:': 4
# 'AM:': 4
# 'DX CHEST PORTABLE PICC LINE PLACEMENT COMPARISON:': 4
# 'AP CHEST INDICATION:': 4
# 'PORTABLE AP INDICATION:': 4
# 'SINGLE FRONTAL CHEST RADIOGRAPH:': 4
# 'IJ COMPARISON:': 4
# 'U COMPARISON:': 4
# 'US:': 4
# 'PORTABLE UPRIGHT FRONTAL CHEST RADIOGRAPH:': 4
# 'A  REASON FOR EXAMINATION:': 4
# 'RIJ CVL COMPARISON:': 4
# 'OG TECHNIQUE:': 4
# 'PA AND LATERAL INDICATION:': 4
# 'FRONTAL SEMI UPRIGHT PORTABLE CHEST:': 4
# 'URI TECHNIQUE:': 4
# 'HCAP IMPRESSION:': 4
# 'HD COMPARISON:': 4
# 'AMS IMPRESSION:': 3
# 'ERCP TECHNIQUE:': 3
# 'COMPARED TO CHEST RADIOGRAPHS THROUGH :': 3
# 'HD TECHNIQUE:': 3
# 'O ABNORMALITY TECHNIQUE:': 3
# 'FRONTAL AND LATERAL VIEWS THE CHEST:': 3
# 'VIEWS:': 3
# 'RLL PNA IMPRESSION:': 3
# 'PORTABLE AP UPRIGHT CHEST FILM AT CLINICAL INDICATION:': 3
# 'EGD TECHNIQUE:': 3
# 'CVA TECHNIQUE:': 3
# 'FOUR IMAGES:': 3
# 'RAY OF FINDINGS:': 3
# 'AT HISTORY:': 3
# 'PTX PTX COMPARISON:': 3
# 'J  HISTORY:': 3
# 'CHEST RADIOGRAPH REASON FOR EXAM:': 3
# 'PORTABLE UPRIGHT CHEST DATED COMPARISON:': 3
# 'CHEST TWO VIEWS INDICATION:': 3
# 'PORTABLE UPRIGHT CHEST OF COMPARISON:': 3
# 'PORTABLE CHEST WITH COMPARISON STUDY OF EARLIER THE SAME DAY FINDINGS:': 3
# 'C IMPRESSION:': 3
# 'PM RESIDENT WET READ:': 3
# 'AM CXR AM CXR IMPRESSION:': 3
# 'CHEST PAIN IMPRESSION:': 3
# 'CHEST RADIOGRAPH INDICATIONS:': 3
# 'CHEST RADIOGRAPH :': 3
# 'SBO COMPARISON:': 3
# 'RIJ CVL TECHNIQUE:': 3
# 'AT INDICATION:': 3
# 'WITH COMPARISON STUDY OF ONE DAY EARLIER FINDINGS:': 3
# 'CTA:': 3
# 'UPRIGHT PORTABLE CHEST RADIOGRAPH:': 3
# 'UPRIGHT FRONTAL AND LATERAL CHEST RADIOGRAPHS:': 3
# 'FINAL ADDENDUM ADDENDUM INDICATION:': 3
# 'SINGLE AP PORTABLE CHEST RADIOGRAPH:': 3
# 'PCP IMPRESSIO :': 3
# 'SINGLE PORTABLE CHEST RADIOGRAPH:': 3
# 'L IJ CVL TECHNIQUE:': 3
# 'AMS CXR:': 3
# 'R IJ CVL TECHNIQUE:': 3
# 'FRONTAL PORTABLE UPRIGHT CHEST:': 3
# 'HYPERTENSION IMPRESSION:': 3
# 'VATS COMPARISON:': 3
# 'NONE AVAILABLE FINDINGS:': 3
# 'PORTABLE UPRIGHT AP CHEST RADIOGRAPH:': 3
# 'PA AND LATERAL CHEST CLINICAL INDICATION:': 3
# 'CHEST RADIOGRAPH IMPRESSION:': 3
# 'WITH NO PRIOR STUDIES FOR COMPARISON FINDINGS:': 3
# 'AM CXR:': 3
# 'PORTABLE CHEST FILM AT INDICATION:': 3
# 'PNX COMPARISON:': 3
# 'AP FRONTAL AND LATERAL CHEST RADIOGRAPHS:': 3
# 'PA AND LATERAL CHEST FROM HISTORY:': 3
# 'CHEST TWO VIEWS COMPARISON:': 3
# 'AP UPRIGHT VIEW OF THE CHEST:': 3
# 'TWO VIEWS FINDINGS:': 3
# 'ERECT PORTABLE CHEST RADIOGRAPH:': 3
# 'IVF COMPARISON:': 3
# 'R IJ TECHNIQUE:': 3
# 'AP UPRIGHT AND LATERAL VIEWS OF THE CHEST:': 3
# 'IP IMPRESSION:': 3
# 'CHEST AND UPPER ABDOMEN:': 3
# 'KUB IMPRESSION:': 3
# 'F TECHNIQUE:': 3
# 'PVT TECHNIQUE:': 3
# 'CHSET RADIOGRAPHS INDICATION:': 3
# 'NG IMPRESSION:': 3
# 'EGD COMPARISON:': 3
# 'AP UPRIGHT CHEST RADIOGRAPH:': 3
# 'BNP TECHNIQUE:': 3
# 'OR COMPARISON:': 3
# 'OR TECHNIQUE:': 3
# 'WITH COMPARISON RADIOGRAPH OF FINDINGS:': 3
# 'CHECK RESOLUTION IMPRESSION:': 3
# 'U IMPRESSION:': 3
# 'LAD IMPRESSION:': 3
# 'HIV PNA TECHNIQUE:': 3
# 'AP CHEST RADIOGRAPH INDICATION:': 3
# 'PPM IMPRESSION:': 3
# 'TX COMPARISON:': 3
# 'FRONTAL AND LATERAL VIEWS CLINICAL INFORMATION:': 3
# 'DHT IMPRESSION:': 3
# 'AM  EXAMINATION:': 3
# 'RUL TECHNIQUE:': 3
# 'OPINION:': 3
# 'SUPINE PORTABLE AP CHEST RADIOGRAPH:': 3
# 'UPRIGHT:': 3
# 'NG COMPARISON:': 3
# 'DKA TECHNIQUE:': 3
# 'L IMPRESSION:': 3
# 'PORTABLE AP UPRIGHT VIEW OF THE CHEST:': 3
# 'ET IMPRESSION:': 3
# 'PA IMPRESSION:': 3
# 'DVT COMPARISON:': 3
# 'IMPESSION:': 3
# 'EKG COMPARISON:': 3
# 'ED TECHNIQUE:': 3
# 'SSCP COMPARISON:': 3
# 'ROTATED POSITIONING:': 3
# 'IP TECHNIQUE:': 3
# 'CHEST PA AND LATERAL FINDINGS:': 3
# 'PORTABLE UPRIGHT CHEST COMPARISON:': 3
# 'EFFUSION COMPARISON:': 3
# 'CXR PORTABLE FILM HISTORY:': 3
# 'O TB TECHNIQUE:': 3
# 'AP INDICATION:': 3
# 'PORTABLE SUPINE AP VIEW OF THE CHEST:': 3
# 'TIA COMPARISON:': 3
# 'EKG TECHNIQUE:': 3
# 'AP PORTABLE CHEST COMPARISON:': 3
# 'INTERVAL CHANGE COMPARISON:': 3
# 'DX CHEST AND RIBS INDICATION:': 3
# 'TYPE OF EXAM:': 3
# 'SUPINE FRONTAL CHEST RADIOGRAPH:': 3
# 'SINGLE PORTABLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 3
# 'PORTABLE UPRIGHT CHEST:': 3
# 'R IJ IMPRESSION:': 3
# 'AP UPRIGHT PORTABLE CHEST RADIOGRAPH:': 3
# 'D CC:': 3
# 'SINGLE AP CHEST RADIOGRAPH:': 3
# 'TIME:': 3
# 'MAIN REPORT CHEST RADIOGRAPHS HISTORY:': 3
# 'OG COMPARISON:': 3
# 'PORTABLE FRONTAL CHEST RADIOGRAPHS:': 3
# 'AP FILM:': 2
# 'INFECTION IMPRESSION:': 2
# 'CHEST PA AND LATERAL COMPARISON:': 2
# 'TYPE OF THE EXAMINATION:': 2
# 'PMA COMPARISON:': 2
# 'TIP IMPRESSION:': 2
# 'SEMIUPRIGHT PORTABLE RADIOGRAPH OF THE CHEST:': 2
# 'CAD COMPARISON:': 2
# 'PA AND LATERAL CHEST ON CLINICAL HISTORY:': 2
# 'PORTABLE SUPINE CHEST DATED COMPARISON:': 2
# 'COMPARISION:': 2
# 'BMT COMPARISON:': 2
# 'RAY WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:': 2
# 'COMPARISON TO PRIOR STUDY:': 2
# 'POD IMPRESSION:': 2
# 'R IJ CVL COMPARISON:': 2
# 'DAH COMPARISON:': 2
# 'RIGHT RIBS:': 2
# 'PPM COMPARISON:': 2
# 'CT INDICATION:': 2
# 'PA AND LATERAL HISTORY:': 2
# 'FINIDNGS:': 2
# 'A IMPRESSION:': 2
# 'LORDOTIC POSITIONING:': 2
# 'CVL CVL TECHNIQUE:': 2
# 'PORTABLE COMPARISON:': 2
# 'PT COMPARISON:': 2
# 'AP PORTABLE CHEST:': 2
# 'WITH COMPARISON STUDY OF EARLIER THE SAME DAY FINDINGS:': 2
# 'O INFILTRATE IMPRESSION:': 2
# 'FX TECHNIQUE:': 2
# 'TX TECHNIQUE:': 2
# 'LP TECHNIQUE:': 2
# 'PE FINDINGS:': 2
# 'LLL PNA COMPARISON:': 2
# 'FAST TRACK EARLY EXTUBATION CARDIAC SURGERY IMPRESSION:': 2
# 'IMPRESSION IMPRESSION:': 2
# 'AM RESIDENT WET READ:': 2
# 'AP PORTABLE:': 2
# 'BIBASILAR RALES IMPRESSION:': 2
# 'CTA TECHNIQUE:': 2
# 'SUPINE FRONTAL VIEW OF THE CHEST:': 2
# 'SINGLE AP PORTABLE VW COMPARISON:': 2
# 'NGT NGT COMPARISON:': 2
# 'TRALI COMPARISON:': 2
# 'CLINIC INDICATION:': 2
# 'F COMPARISON:': 2
# 'IABP EXAMINATION:': 2
# 'CHEST ULTRASOUND INDICATION:': 2
# 'ERECT PORTABLE AP CHEST RADIOGRAPH:': 2
# 'CHEST PA:': 2
# 'ERECT PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:': 2
# 'ARDS FINDINGS:': 2
# 'FRONTAL PORTABLE SUPINE CHEST:': 2
# 'CT  EXAMINATION:': 2
# 'T FINDINGS:': 2
# 'CHEST RADIOGRAPHS INDICATIONS:': 2
# 'CHEST AP SUPINE:': 2
# 'CTX IMPRESSION:': 2
# 'FRONTAL VIEWS OF THE CHEST REASON FOR EXAM:': 2
# 'ILD:': 2
# 'ICU CXR COMPARISON:': 2
# 'RHC TECHNIQUE:': 2
# 'O PULMONARY EDEMA IMPRESSION:': 2
# 'PORTABLE SUPINE CHEST COMPARISON:': 2
# 'CHEST RADIOGRAPH DATED COMPARISON:': 2
# 'N TECHNIQUE:': 2
# 'IP COMPARISON:': 2
# 'FRONTAL AND LATERAL VIEWS CHEST:': 2
# 'PLEURAL EFFUSIONS IMPRESSION:': 2
# 'P TECHNIQUE:': 2
# 'PORTABLE UPRIGHT AP VIEW OF THE ABDOMEN:': 2
# 'RUQ COMPARISON:': 2
# 'SUPINE PORTABLE FRONTAL CHEST RADIOGRAPH:': 2
# 'CHEST TWO VIEWS :': 2
# 'HCAP TECHNIQUE:': 2
# 'CXR CHANGES IMPRESSION:': 2
# 'AP AND LATERAL CHEST RADIOGRAPH DATED COMPARISON:': 2
# 'CP PTX TECHNIQUE:': 2
# 'R PNA TECHNIQUE:': 2
# 'UPRIGHT RADIOGRAPH OF THE CHEST:': 2
# 'CHEST RADIOGRAPH CLINICAL HISTORY:': 2
# 'PA AND LATERAL CHEST RADIOGRAPH OF WITH NO PRIOR STUDIES FOR COMPARISON FINDINGS:': 2
# 'TACO TECHNIQUE:': 2
# 'VQ TECHNIQUE:': 2
# 'IMPRESSON:': 2
# 'AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 2
# 'SICU:': 2
# 'P COMPARISON:': 2
# 'PORTABLE RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 2
# 'PA AND LATERAL CHEST RADIOGRAPH :': 2
# 'SEMISUPINE:': 2
# 'HTN TECHNIQUE:': 2
# 'PORTABLE RADIOGRAPH OF THE CHEST:': 2
# 'UPRIGHT VIEW OF THE CHEST:': 2
# 'PRIOR CHEST RADIOGRAPHS IMPRESSION:': 2
# 'TACE TECHNIQUE:': 2
# 'FRONTAL VIEWS OF THE CHEST:': 2
# 'RAY ON COMPARISON:': 2
# 'AT FINDINGS:': 2
# 'CHEST RADIOGRAPHS :': 2
# 'HOURS INDICATION:': 2
# 'COMPARISON EXAMS:': 2
# 'STEMI COMPARISON:': 2
# 'NGT NGT NGT IMPRESSION:': 2
# 'RESOLUTION IMPRESSION:': 2
# 'MS TECHNIQUE:': 2
# 'TWO PORTABLE AP VIEWS OF THE CHEST:': 2
# 'TLC COMPARISON:': 2
# 'POC COMPARISON:': 2
# 'U PNA IMPRESSION:': 2
# 'PT IMPRESSION:': 2
# 'IVF IMPRESSION:': 2
# 'SOB SOB IMPRESSION:': 2
# 'CHEST FRONTAL AND LATERAL VIEWS CLINICAL INFORMATION:': 2
# 'POSITIVE PPD IMPRESSION:': 2
# 'REASON FOR THIS EXAMINATION:': 2
# 'AP AND LATERAL RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 2
# 'I IMPRESSION:': 2
# 'DYSPNEA COMPARISON:': 2
# 'CP CP TECHNIQUE:': 2
# 'RCU TECHNIQUE:': 2
# 'R TECHNIQUE:': 2
# 'PORTABLE AP FRONTAL VIEW OF THE CHEST:': 2
# 'ERECT PORTABLE VIEW OF THE CHEST:': 2
# 'MAIN REPORT INDICATION:': 2
# 'R IJ COMPARISON:': 2
# 'ET COMPARISON:': 2
# 'SINGLE UPRIGHT PORTABLE CHEST RADIOGRAPH:': 2
# 'SINGLE PORTABLE UPRIGHT CHEST RADIOGRAPH:': 2
# 'FINSINGS:': 2
# 'THREE IMAGES:': 2
# 'U TECHNIQUE:': 2
# 'CP PNA TECHNIQUE:': 2
# 'RLL PNA COMPARISON:': 2
# 'MS COMPARISON:': 2
# 'FINAL ADDENDUM ADDENDUM :': 2
# 'EVAL IMPRESSION:': 2
# 'CHF CHF TECHNIQUE:': 2
# 'R VATS IMPRESSION:': 2
# 'MASS COMPARISON:': 2
# 'CHEST PORTABLE PLAIN FILM AT CLINICAL INDICATION:': 2
# 'PORTABLE CHEST ON HISTORY:': 2
# 'AM ON IMPRESSION:': 2
# 'SINGLE FRONTAL VIEWS OF THE CHEST REASON FOR EXAM:': 2
# 'TIPS TECHNIQUE:': 2
# 'TBP IMPRESSION:': 2
# 'UPRIGHT FILM HISTORY:': 2
# 'ICU IMPRESSION:': 2
# 'A COMPARISON:': 2
# 'O CHF IMPRESSION:': 2
# 'R PTX R PTX COMPARISON:': 2
# 'CHEST SUPINE COMPARISON:': 2
# 'MULTIPLE FRONTAL CHEST RADIOGRAPHS COMPARISON:': 2
# 'SINGLE SUPINE PORTABLE VIEW OF THE CHEST:': 2
# 'COPD NOTIFICATION:': 2
# 'XR:': 2
# 'HISTORY :': 2
# 'CTA NOTIFICATION:': 2
# 'CONCLUSION :': 2
# 'SINGLE PORTABLE VIEW OF THE CHEST COMPARISON:': 2
# 'PAC COMPARISON:': 2
# 'TIA TECHNIQUE:': 2
# 'AM AM COMPARISON:': 2
# 'ERECT FRONTAL CHEST RADIOGRAPHS:': 2
# 'TTP TECHNIQUE:': 2
# 'ASSESSMENT AND PLAN:': 2
# 'CHEST AP AND LATERAL INDICATION:': 2
# 'ERECT CHEST:': 2
# 'CX IMPRESSION:': 2
# 'PORTABLE CHEST COMPARISON STUDY:': 2
# 'CTA :': 2
# 'CHEST PA AND LATERAL RADIOGRAPH:': 2
# 'L IJ TECHNIQUE:': 2
# 'AP :': 2
# 'UPRIGHT PORTABLE AP RADIOGRAPH OF THE CHEST:': 2
# 'LATERAL VIEWS CHEST:': 2
# 'SOURCE IMPRESSION:': 2
# 'CXR SINGLE PORTABLE FILM HISTORY:': 2
# 'TX IMPRESSION:': 2
# 'V ICD IMPRESSION:': 2
# 'A TECHNIQUE:': 2
# 'OSH IMPRESSION:': 2
# 'PLS EVAL FOR PNA IMPRESSION:': 2
# 'UPRIGHT PA AND LATERAL VIEWS OF THE CHEST:': 2
# 'POD COMPARISON:': 2
# 'O INFILTRATE TECHNIQUE:': 2
# 'PLEASE DO AT NOON IMPRESSION:': 2
# 'AP AND LATERAL CHEST ON HISTORY:': 2
# 'PORTABLE AP RADIOGRAPH OF THE CHEST:': 2
# 'CHEST PORTABLE AP INDICATION:': 2
# 'U PTX TECHNIQUE:': 2
# 'SVC NOTIFICATION:': 2
# 'SOB PNA COMPARISON:': 2
# 'CHF CHF COMPARISON:': 2
# 'UPRIGHT PORTABLE AP CHEST RADIOGRAPH:': 2
# 'SUPINE PORTABLE RADIOGRAPH OF THE CHEST:': 2
# 'PORT COMPARISON:': 2
# 'AM ON TECHNIQUE:': 2
# 'AP VIEWS OF THE CHEST:': 2
# 'RAY FROM AT :': 2
# 'SVT TECHNIQUE:': 2
# 'AP CHEST ON :': 2
# 'PA AND LATERAL ON HISTORY:': 2
# 'PERSISTENT COUGH TECHNIQUE:': 2
# 'RUL IMPRESSION:': 2
# 'PNA:': 2
# 'PLEURAL EFFUSION IMPRESSION:': 2
# 'VATS IMPRESSION:': 2
# 'HTX IMPRESSION:': 2
# 'RVR IMPRESSION:': 2
# 'O CONSOLIDATION IMPRESSION:': 2
# 'RAYS DATED COMPARISON:': 2
# 'RIJ CVL IMPRESSION:': 2
# 'PA AND LATERAL CHEST RADIOGRAPHS :': 2
# 'CHEST RADIOGRAPHS PERFORMED ON COMPARISON:': 2
# 'PA AND LATERAL CHEST CLINICAL HISTORY:': 2
# 'PELVIS:': 2
# 'STAT IMPRESSION:': 2
# 'PORTABLE AP AND LATERAL CHEST RADIOGRAPHS:': 2
# 'CHRONIC COUGH IMPRESSION:': 2
# 'BMT IMPRESSION:': 2
# 'WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DATE FINDINGS:': 2
# 'WEEKS IMPRESSION:': 2
# 'DOE SOB COMPARISON:': 2
# 'XR TECHNIQUE:': 2
# 'INTERVAL CHANGES IMPRESSION:': 2
# 'CAD TECHNIQUE:': 2
# 'WOB COMPARISON:': 2
# 'ERECT CHEST FILM CLINICAL INDICATION:': 2
# 'CAP IMPRESSION:': 2
# 'SBO TECHNIQUE:': 2
# 'MR IMPRESSION:': 2
# 'ERECT CHEST RADIOGRAPHS:': 2
# 'AP CHEST RADIOGRAPHS INDICATION:': 2
# 'MAIN REPORT CHEST RADIOGRAPHS INDICATION:': 2
# 'AND IMPRESSION:': 2
# 'ICU COMPARISON:': 2
# 'CONFIRM PLACEMENT COMPARISON:': 2
# 'PORTABLE VIEW:': 2
# 'ONE VIEW:': 2
# 'AT HOURS CLINICAL INDICATION:': 2
# 'STEMI TECHNIQUE:': 2
# 'O CHF OR PNEUMONIA IMPRESSION:': 1
# 'AP FRONTAL CHEST RADIOGRAPH:': 1
# 'PNA CXR TECHNIQUE:': 1
# 'ARDS ARDS ARDS IMPRESSION:': 1
# 'LUNG LESION COUGH SPUTUM SOB COMPARISON:': 1
# 'PA AND LATERAL CHEST FROM ON HISTORY:': 1
# 'PLEASE DO AT IN THE MORNING IMPRESSION:': 1
# 'RIB FX IMPRESSION:': 1
# 'O NODULES IMPRESSION:': 1
# 'BONES ARE DIFFUSELY DEMINERALIZED IMPRESSION:': 1
# 'R PNX COMPARISON:': 1
# 'RAY OF ONE DAY EARLIER FINDINGS:': 1
# 'BMT EVALUATION IMPRESSION:': 1
# 'OPACITY IMPRESSION:': 1
# 'DISEASE IMPRESSION:': 1
# 'FRONTAL AND LATERAL RADIOGRAPHS:': 1
# 'SEMI ERECT INDICATION:': 1
# 'ON COMPARISON:': 1
# 'SUPINE CHEST RADIOGRAPH:': 1
# 'O PE COMPARISON:': 1
# 'CHEST PORTABLE AT INDICATION:': 1
# 'VIEW CHEST COMPARISON:': 1
# 'IVF TECHNIQUE:': 1
# 'ON EXAM IMPRESSION:': 1
# 'SOB CT:': 1
# 'PTX INTERVAL CHANGE INTERVAL CHANGE IMPRESSION:': 1
# 'UPRIGHT FRONTAL CHEST RADIOGRAPHS:': 1
# 'ASN IMPRESSION:': 1
# 'PERICARDIAL PATHOLOGY IMPRESSION:': 1
# 'TAVR CXR IMPRESSION:': 1
# 'ETT PLACEMENT IMPRESSION:': 1
# 'O NEW COMPRESSION FRACTURE AND QUESTION LYMPHADENOPATHY IMPRESSION:': 1
# 'VWS COMPARISON:': 1
# 'O TB COMPARISON:': 1
# 'FINDINGS COMPARISON:': 1
# 'PM  INDICATION:': 1
# 'PT ON AMIDOARONE EVAL FOR SIGNS OF AMIO TOXICITY IMPRESSION:': 1
# 'PLEASE DO AT IMPRESSION:': 1
# 'PLEASE TAKE AT COMPARISON:': 1
# 'ESRD COMPARISON:': 1
# 'CHEST RADIOGRAPHS FROM FINDINGS:': 1
# 'SAH PNEUMONIA TECHNIQUE:': 1
# 'HX OF SMOKING COMPARISON:': 1
# 'PLEASE DO AT AM IMPRESSION:': 1
# 'SDH IMPRESSION:': 1
# 'PREOP CHEST RADIOGRAPH INDICATION:': 1
# 'DOUBLE CHEST RADIOGRAPH:': 1
# 'BMT TECHNIQUE:': 1
# 'HEART SIZE IS UPPER LIMITS NORMAL IMPRESSION:': 1
# 'NEW ABNORMALITY IMPRESSION:': 1
# 'OG IMPRESSION:': 1
# 'INFILTRATES COMPARISON:': 1
# 'MD  EXAMINATION:': 1
# 'PORTABLE SUPINE CHEST FILM AT CLINICAL INDICATION:': 1
# 'MOST RECENT PRIOR RADIOGRAPH ON FINDINGS:': 1
# 'PNEUMONIA FOLLOW UP ON PNEUMONIA TECHNIQUE:': 1
# 'PORTABLE CHEST WITH NO COMPARISON FINDINGS:': 1
# 'PLEASE PERFORM AT PM TODAY TECHNIQUE:': 1
# 'RN IMPRESSION:': 1
# 'NOW TECHNIQUE:': 1
# 'PA AND LATERAL CHEST RADIOGRAPH DATED WITH NO PRIOR RADIOGRAPHS FOR COMPARISON FINDINGS:': 1
# 'READ IN CONJUNCTION WITH CHEST CTA :': 1
# 'SINGLE FRONTAL CHEST RADIOGRAPHS:': 1
# 'A PORTABLE AP CHEST FILM AT INDICATION:': 1
# 'SINGLE AP PORTABLE VIEW OF THE CHEST COMPARISON:': 1
# 'WERE FINDINGS:': 1
# 'O ATELECTASIS VS EARLY RT BASE INFECTION IMPRESSION:': 1
# 'PRIOR CHEST RADIOGRAPHS THROUGH :': 1
# 'CH TECHNIQUE:': 1
# 'U CHEST XRAY IMPRESSION:': 1
# 'FN IMPRESSION:': 1
# 'NSGY TECHNIQUE:': 1
# 'NONE AVAIL FINDINGS:': 1
# 'RESPITORY FAILURE NGT PLACEMENT NGT PLACEMENT IMPRESSION:': 1
# 'FEVER AND SHORTNESS OF BREATH ROLE OUT PNEUMONIA TECHNIQUE:': 1
# 'O INDICATION:': 1
# 'AM PRELIMINARY RESIDENT WET READ:': 1
# 'OG TUBE POSITION AND LUNG STATUS COMPARISON:': 1
# 'AP IMPRESSION:': 1
# 'TWO VIEWS OF THE THORACIC SPINE:': 1
# 'IABP FAST TRACK EARLY EXTUBATION CARDIAC SURGERY FAST TRACK EARLY EXTUBATION CARDIAC SURGERY IMPRESSION:': 1
# 'FINDNINGS:': 1
# 'PRE LUNG SCAN COMPARISON:': 1
# 'CTP:': 1
# 'EVALUATE STATUS COMPARISON:': 1
# 'COUGH TECHNIQUE:': 1
# 'O ACTIVE TB ABNORMALITY IMPRESSION:': 1
# 'PORTABLE UPRIGHT AP CHEST RADIOGRAPH FINDINGS:': 1
# 'WS COMPARISON:': 1
# 'BAL COMPARISON:': 1
# 'IS IMPRESSION:': 1
# 'THERE ARE MILD DEGENERATIVE CHANGES IN THE THORACIC SPINE IMPRESSION:': 1
# 'FIMPRESSION:': 1
# 'HYPERTENSION AND HYPERLIPIDEMIA IMPRESSION:': 1
# 'PA AND LEFT LATERAL CHEST FILM AT CLINICAL INDICATION:': 1
# 'SIGNS OF LATENT TB IMPRESSION:': 1
# 'LUNG PATHOLOGY IMPRESSION:': 1
# 'CM L BRACHIAL DL TECHNIQUE:': 1
# 'ACTIVE TBC COMPARISON:': 1
# 'PCP PNA COMPARISON:': 1
# 'SMALL INDENTATION ON THE LEFT SIDE OF THE TRACHEA AT THE THORACIC INLET IS MOST COMMONLY DUE TO A LARGE LEFT THYROID LOBE IMPRESSION:': 1
# 'AS COMPARISON:': 1
# 'THEY REPORT TEXT FOLLOWS:': 1
# 'CARDIOPULMONARY ABNL COMPARISON:': 1
# 'LEFT SIDED CHEST PAIN COMPARISON:': 1
# 'HOURS CLINICAL INDICATION:': 1
# 'AP UPRIGHT AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:': 1
# 'TARGETED REVIEW OF CHEST CT FROM FINDINGS:': 1
# 'KYPHOTIC POSITIONING:': 1
# 'POST TAVR TAVR POSITION TAVR POSITION IMPRESSION:': 1
# 'OG TUBE IMPRESSION:': 1
# 'CHEST AP AND LAT INDICATION:': 1
# 'FRONTAL AND LATERAL CHEST RADIOGRAPHS COMPARISON:': 1
# 'VQ IMPRESSION:': 1
# 'MM LEFT PECTORAL SUBCUTANEOUS OR SUPERFICIAL RADIOPAQUE MATERIAL SHOULD BE LOCALIZED CLINICALLY IMPRESSION:': 1
# 'CHEST PA AND LAT RADIOGRAPH:': 1
# 'ARF TECHNIQUE:': 1
# 'PORTABLE RADIOGRAPHS COMPARISON:': 1
# 'NEW OG TUBE PLACEMENT IMPRESSION:': 1
# 'OF THE THORAX INDICATION:': 1
# 'FINAL ADDENDUM ADDENDUM IMPRESSION:': 1
# 'FOLLOWUP OF RIGHT LOWER LOBE PNEUMONIA TECHNIQUE:': 1
# 'FINAL ADDENDUM CHEST PA AND LATERAL AMENDMENT:': 1
# 'CHEST AND RIBS HISTORY:': 1
# 'PA AND LATERAL CHEST RADIOGRAPH OF :': 1
# 'QUESTION ACIVE TB IMPRESSION:': 1
# 'O CHF VS COPD EXACERBATION IMPRESSION:': 1
# 'PORTABLE AP AND LATERAL CHEST RADIOGRAPH:': 1
# 'UPRIGHT AP AND LATERAL CHEST RADIOGRAPHS:': 1
# 'HCF PNA TECHNIQUE:': 1
# 'LUNG FIELDS IMPRESSION:': 1
# 'TRAUMA TECHNIQUE:': 1
# 'PORTABLE RADIOGRAPH:': 1
# 'CHEST AP COMPARISON FILMS:': 1
# 'SOB CHF TECHNIQUE:': 1
# 'PORTABLE ERECT RADIOGRAPH:': 1
# 'WEEKS COMPARISON:': 1
# 'UPRIGHT RADIOGRAPH:': 1
# 'O TECHNIQUE:': 1
# 'U ABNML CXR COMPARISON:': 1
# 'AVR TECHNIQUE:': 1
# 'REASON FORE EXAM:': 1
# 'PREVIOUS SMOKER IMPRESSION:': 1
# 'ET ETT ETT IMPRESSION:': 1
# 'MVA IMPRESSION:': 1
# 'PA AND LATERAL CHEST OF WITH COMPARISON STUDY OF EARLIER THE SAME DATE FINDINGS:': 1
# 'RML IMPRESSION:': 1
# 'OBTAINED EARLIER IMPRESSION:': 1
# 'SINGLE AP SUPINE PORTABLE VIEW:': 1
# 'PA AND LATERAL CHEST FILM ON AT CLINICAL INDICATION:': 1
# 'PLEASE PERFORM AT COMPARISON:': 1
# 'EVAL INTERVAL CHANGE IMPRESSION:': 1
# 'WE ARE MONITORING FOR EXPANDING PTX WHILE ON WATER SEAL IMPRESSION:': 1
# 'PM CHECK FOR PNEUMO IMPRESSION:': 1
# 'POST INTUBATION CHECK AND OG TUBE PLACEMENT COMPARISON:': 1
# 'FEVER COUGH AND CRACKLES OVER THE RIGHT LUNG PNEUMONIA COMPARISON:': 1
# 'SINGLE PORTABLE UPRIGHT VIEW OF THE CHEST:': 1
# 'CHEST REVIEWED INDICATION:': 1
# 'PLEASE CHECK PLEURAL EFFUSION IMPRESSION:': 1
# 'TECHNIQUE PA AND LATERAL VIEWS OF THE CHEST:': 1
# 'COR:': 1
# 'WOB PNA COMPARISON:': 1
# 'SINGLE AP VIEW OF THE CHEST COMPARISON:': 1
# 'PLEASE EVALUATE STATUS POST FOLLOWUP IMPRESSION:': 1
# 'EVAL PLEURITIC PAIN IN THE SETTING OF LEFT FOOT SWELLING TECHNIQUE:': 1
# 'SOFT LUMP IMPRESSION:': 1
# 'PATIENT MUST STAY FLAT TECHNIQUE:': 1
# 'PEEP IMPRESSION:': 1
# 'INFILTRATE COMPARISON:': 1
# 'RFA COMPARISON:': 1
# 'ICD EVALUATE FOR PNEUMOTHORAX AND LEAD PLACEMENT TECHNIQUE:': 1
# 'OTHER TECHNIQUE:': 1
# 'MODERATE TO LARGE RIGHT AND SMALL LEFT PLEURAL EFFUSIONS NOTIFICATION:': 1
# 'V PPM COMPARISON:': 1
# 'NP TECHNIQUE:': 1
# 'PNEUMOTHORAX IMPRESSION:': 1
# 'VATS TECHNIQUE:': 1
# 'SINGLE PORTAL VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'RL PNA PNA COMPARISON:': 1
# 'ERECT RADIOGRAPH:': 1
# 'TF IMPRESSION:': 1
# 'CHYLOTHORAX AFTER MVC IMPRESSION:': 1
# 'BS COMPARISON:': 1
# 'AMS XR:': 1
# 'R DVT TECHNIQUE:': 1
# 'PA L IMPRESSION:': 1
# 'FRONTAL CHEST RADIOGRAPH WITH THE PATIENT IN SUPINE AND UPRIGHT POSITIONS:': 1
# 'CHF PNA PNA IMPRESSION:': 1
# 'PA AND LATERAL CHEST OF WITH COMPARISON FINDINGS:': 1
# 'SINGLE AP PORTABLE VIEW WHICH INCLUDES THE UPPER ABDOMEN:': 1
# 'CHEST RADIOGRAPH NDICATION:': 1
# 'TBI TECHNIQUE:': 1
# 'INTERVAL CAHNGE IMPRESSION:': 1
# 'CHRONIC COUGH COMPARISON:': 1
# 'IJ INDICATION:': 1
# 'O TB IMPRESSION:': 1
# 'AP PORTABLE UPRIGHT CHEST RADIOGRAPH:': 1
# 'ICU HYPOXIA IMPRESSION:': 1
# 'SMOKING HX IMPRESSION:': 1
# 'PORTABLE UPRIGHT RADIOGRAPH CHEST:': 1
# 'ILLNESS:': 1
# 'O PATHOLOGY IMPRESSION:': 1
# 'O INFILTRATE COMPARISON:': 1
# 'PORTABLE CHEST RADIOGRAPH WITH COMPARISON RADIOGRAPH FINDINGS:': 1
# 'WITH COMPARISON TO RADIOGRAPH FINDINGS:': 1
# 'PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH FINDINGS:': 1
# 'DEGREES INDICATION:': 1
# 'AT COMPARISON:': 1
# 'HEADACHE AND LEUKOCYTOSIS INFECTION COMPARISON:': 1
# 'NONE TECHNIQUE:': 1
# 'EMS TECHNIQUE:': 1
# 'ASSESS FOR PLEURAL EFFUSION COMPARISON:': 1
# 'WET READ PLEASE COMPARISON:': 1
# 'CHEST RADIOGRAPHS SINCE MOST RECENTLY FINDINGS:': 1
# 'U PNEUMONIA RESIDUAL CHECK RESOLUTION NO COUGH IMPRESSION:': 1
# 'RAY AP COMPARISON:': 1
# 'OSSEOUS STRUCTURES:': 1
# 'FRONTAL PORTABLE UPRIGHT RADIOGRAPH:': 1
# 'TKR COMPARISON:': 1
# 'WITH COMPARISON CHEST OF EARLIER THE SAME DATE FINDINGS:': 1
# 'THANK YOU COMPARISON:': 1
# 'CT FROM AND CHEST RADIOGRAPH FROM FINDINGS:': 1
# 'INCREASING CHEST PAIN AND DISTRESS IMPRESSION:': 1
# 'P TAVR TECHNIQUE:': 1
# 'INCIPIENT CHF IMPRESSION:': 1
# 'O PULMONARY PROCESS COMPARISON:': 1
# 'CT FROM FINDINGS:': 1
# 'AM SLIGHT IMPROVEMENT IN NEAR COMPLETE OPACIFICATION OF THE LEFT HEMITHORAX  EXAMINATION:': 1
# 'SARCOID IMPRESSION:': 1
# 'CRRT CRRT COMPARISON:': 1
# 'STATUS POST LIVER TRANSPLANT WITH LIVER FAILURE TECHNIQUE:': 1
# 'AP UPRIGHT AND LATERAL VIEWS HISTORY:': 1
# 'PRIOR IMPRESSION:': 1
# 'LAT CXR COMPARISON:': 1
# 'GVHD:': 1
# 'BRONCHITIS OR PNEUMONIA IMPRESSION:': 1
# 'O LESION OR FLUID COMPARISON:': 1
# 'NGT NGT EXAMINATION:': 1
# 'INFILTRATE TACHYPNEA DESATURATION IMPRESSION:': 1
# 'D TECHNIQUE:': 1
# 'GPA COMPARISON:': 1
# 'O ABNORMALIYT IMPRESSION:': 1
# 'RIJ TLC IMPRESSION:': 1
# 'RUL PNA COMPARISON:': 1
# 'SENSATION OF ZAPS ACROSS UPPER CHEST IMPRESSION:': 1
# 'RADIOGRAPHS HISTORY:': 1
# 'RUQUS:': 1
# 'CHEST RADIOGRAPH AND EKG INDICATION:': 1
# 'POST PLACEMENT CHEST XRAY TO CONFIRM TIP PLACEMENT IMPRESSION:': 1
# 'POST PLACEMENT TO CONFIRM TIP PLACEMENT IMPRESSION:': 1
# 'CHEST RADIOGRAPH FROM FINDINGS:': 1
# 'TAH COMPARISON:': 1
# 'SERIES OF RADIOGRAPHS OBTAINED FOR ASSESSMENT OF NASOGASTRIC TUBE PLACEMENT COMPARISON:': 1
# 'CHEST WITH LATERAL COMPARISON FILM:': 1
# 'LESION IMPRESSION:': 1
# 'VIEW CHEST HISTORY:': 1
# 'CT WOULD BE NECESSARY FOR PRECISE VISUALIZATION  EXAMINATION:': 1
# 'INH TB TB IMPRESSION:': 1
# 'CVL EXAMINATION:': 1
# 'MEDIASTINAL CONTOURS ARE UNREMARKABLE NOTIFICATION:': 1
# 'I MPRESSION:': 1
# 'RIGHT RIB RESECTION WITH ELOESSOR FLAP COMPARISON:': 1
# 'FINGDINGS:': 1
# 'LINE PLACEMENT TECHNIQUE:': 1
# 'RLE TECHNIQUE:': 1
# 'ASSES OG TUBE PLACEMENT COMPARISON:': 1
# 'ASSESS FOR RESOLUTION IMPRESSION:': 1
# 'GUIDANCE FINDINGS:': 1
# 'REMOTE HEAVY EXPOSURE COMPARISON:': 1
# 'PTB IMPRESSION:': 1
# 'PLEASE DO AT COMPARISON:': 1
# 'CHOCTAW:': 1
# 'M ICU M ICU IMPRESSION:': 1
# 'PORTABLE AP UPRIGHT FINDINGS:': 1
# 'PNA LLL TECHNIQUE:': 1
# 'CXR AM COMPARISON:': 1
# 'SUBCUTANEOUS ICD COMPARISON:': 1
# 'US TECHNIQUE:': 1
# 'CHEST SINGLE VIEW ON HISTORY:': 1
# 'MYLTIPLE MYELOMA CHECK PLEURAL EFFUSION IMPRESSION:': 1
# 'HH IMPRESSION:': 1
# 'AD TECHNIQUE:': 1
# 'CVICU TECHNIQUE:': 1
# 'O CONSOLIDATION ABNORMALITY WET READING P IMPRESSION:': 1
# 'FATHER HAD PNEUMONIA IMPRESSION:': 1
# 'P ENDOVASCULAR IMPRESSION:': 1
# 'PNA ON VENTILATOR ON VENTILATOR IMPRESSION:': 1
# 'PA AND LATERAL CHEST RADIOGRAPH OF FINDINGS:': 1
# 'FRONTAL AP AND LATERAL CHEST:': 1
# 'CHEST RADIOGRAPH OF COMPARISON:': 1
# 'CT CT CT IMPRESSION:': 1
# 'CT CT TECHNIQUE:': 1
# 'SIADH IMPRESSION:': 1
# 'AF COMPARISON:': 1
# 'ETIOLOGY IMPRESSION:': 1
# 'DM SOB CHF CHF IMPRESSION:': 1
# 'PLEASE EVALUATE POSSIBLE CAUSE OF NIGHT SWEATS IMPRESSION:': 1
# 'ABDOMEN RADIOGRAPHS:': 1
# 'DISCITIS IMPRESSION:': 1
# 'SINGLE VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'CHEST FRONTAL AND LATERAL COMPARISON:': 1
# 'COMPARISON FILMS:': 1
# 'U RLL PNA IMPRESSION:': 1
# 'PORTABLE UPRIGHT CHEST RADIOGRAPH OF COMPARISON:': 1
# 'O C A PNEUMONIA IMPRESSION:': 1
# 'SEE IMPRESSION BELOW IMPRESSION:': 1
# 'ET TUBE TIP FINDINGS:': 1
# 'O LUNG PATHOLOGY IMPRESSION:': 1
# 'FIVE IMAGES:': 1
# 'PELVIS RADIOGRAPH PERFORMED ON COMPARISON:': 1
# 'L NS TECHNIQUE:': 1
# 'SINGLE AP PORTABLE CHEST RADIOGRAPH DATED COMPARISON:': 1
# 'GSW TECHNIQUE:': 1
# 'CEHST RADIOGRAPH INDICATION:': 1
# 'AMS RUQ:': 1
# 'STEMI CHF CHF IMPRESSION:': 1
# 'PICC LINE IMPRESSION:': 1
# 'MASS IMPRESSION:': 1
# 'PIE IMPRESSION:': 1
# 'SUPINE PORTABLE CHEST COMPARISON:': 1
# 'PORTABLE UPRIGHT AP VIEW OF THE CHEST INDICATION:': 1
# 'ETT CXR TECHNIQUE:': 1
# 'FOR INTERVENTIONAL PULM TO ASSESS IMPRESSION:': 1
# 'Q COMPARISON:': 1
# 'US IMPRESSION:': 1
# 'SINGLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 1
# 'AP AND LATERAL UPRIGHT CHEST RADIOGRAPH INDICATION:': 1
# 'FA COMPARISON:': 1
# 'PA:': 1
# 'STAT PCXR IMPRESSION:': 1
# 'PORTABLE CHEST ON AT CLINICAL INDICATION:': 1
# 'NOON ON HISTORY:': 1
# 'REUIQREMENT IMPRESSION:': 1
# 'FINAL ADDENDUM INDICATION:': 1
# 'PA AND LATERAL CHEST FILMS:': 1
# 'BEDSIDE FRONTAL CHEST RADIOGRAPH:': 1
# 'CHEST COMPARISON CHEST:': 1
# 'BEDSIDE AP UPRIGHT RADIOGRAPH OF THE CHEST:': 1
# 'D CXR:': 1
# 'IR TECHNIQUE:': 1
# 'O EFFUSIONS COMPARISON:': 1
# 'TPN TECHNIQUE:': 1
# 'CHEST RATE IMPRESSION:': 1
# 'UA COMPARISON:': 1
# 'PA AND LATERAL CHEST IMPRESSION:': 1
# 'PORTABLE CHEST WITH COMPARISON STUDY OF ONE DAY EARLIER FINDINGS:': 1
# 'CT TORSO FROM IMPRESSION:': 1
# 'COPD  EXAMINATION:': 1
# 'FA IMPRESSION:': 1
# 'PORTABLE CHEST WALL INDICATION:': 1
# 'AM CXR TECHNIQUE:': 1
# 'PT SOB IMPRESSION:': 1
# 'EF IMPRESSION:': 1
# 'R BASE IMPRESSION:': 1
# 'UPRIGHT VIEW:': 1
# 'AP AND LATERAL VIEWS OF THE CHEST COMPARISON:': 1
# 'PA AND LATERAL CHEST OF :': 1
# 'COMPARRISON:': 1
# 'FINDINS:': 1
# 'ASPIRATION PNA TECHNIQUE:': 1
# 'AA IMPRESSION:': 1
# 'ACUTE PROCESS TECHNIQUE:': 1
# 'P ETT TECHNIQUE:': 1
# 'CPD COMPARISON:': 1
# 'PA AND LATERAL UPRIGHT CHEST RADIOGRAPHS:': 1
# 'EVALUATE FOR MALIGNANCY COMPARISON:': 1
# 'PORTABLE SUPINE CHEST FILM FROM AT CLINICAL INDICATION:': 1
# 'KUB:': 1
# 'WITH COMPARISON CHEST RADIOGRAPHS OF AND FINDINGS:': 1
# 'PLEASE DO CXR ON TECHNIQUE:': 1
# 'WBC PNA COMPARISON:': 1
# 'BS TECHNIQUE:': 1
# 'SAH IMPRESSION:': 1
# 'R PICC COMPARISON:': 1
# 'CRACKLES COMPARISON:': 1
# 'THERE NO PRIOR CHEST RADIOGRAPHS AVAILABLE FOR REVIEW IMPRESSION:': 1
# 'HF IMPRESSION:': 1
# 'TODAY TECHNIQUE:': 1
# 'TTE TECHNIQUE:': 1
# 'L PTX TECHNIQUE:': 1
# 'CHILLS COMPARISON:': 1
# 'OLT COMPARISON:': 1
# 'COPD COPD IMPRESSION:': 1
# 'L CT IMPRESSION:': 1
# 'PACS IMPRESSION:': 1
# 'POST INFLUENZA PNA IMPRESSION:': 1
# 'EVALUATE IMPRESSION:': 1
# 'A PTX TECHNIQUE:': 1
# 'ACUTE CARDIOPULM DSIEASE TECHNIQUE:': 1
# 'AM CHECK INTERVAL CHANGE IMPRESSION:': 1
# 'SUPINE CHEST:': 1
# 'PORTABLE SUPINE CHEST:': 1
# 'ASSESS IF NEW LLL OPACITY SEEN ON CHEST CT VISIBLE ON CXR IMPRESSION:': 1
# 'OBSTRUCTION IMPRESSION:': 1
# 'EVAL FOR INTERVAL CHANGE EVAL FOR INTERVAL CHANGE COMPARISON:': 1
# 'DIFFUSE WHEEZING IMPRESSION:': 1
# 'FINDINGS FINDINGS:': 1
# 'IV RN COMPARISON:': 1
# 'VT TECHNIQUE:': 1
# 'CHF SOB TECHNIQUE:': 1
# 'SIDED PICC LINE TIP IS A IN THE RIGHT ATRIUM JUST BELOW THE CAVOATRIAL JUNCTION IMPRESSION:': 1
# 'AM CXR AM CXR COMPARISON:': 1
# 'AP UPRIGHT COMPARISON:': 1
# 'RIGHT AND LEFT FRONTAL OBLIQUE VIEWS OF THE CHEST:': 1
# 'SUBDURAL HEMATOMA TECHNIQUE:': 1
# 'PA AND LAT:': 1
# 'CXR :': 1
# 'CHEST AND PELVIS FILMS:': 1
# 'PRIOR STUDY DATED AND FINDINGS:': 1
# 'PT HAS SOB AND COUGH IMPRESSION:': 1
# 'NG PLACEMENT IMPRESSION:': 1
# 'W TECHNIQUE:': 1
# 'SEVERE TR IMPRESSION:': 1
# 'CHRONUC COUGH IMPRESSION:': 1
# 'ASD TECHNIQUE:': 1
# 'STAT COMPARISON:': 1
# 'AP SUPINE CHEST RADIOGRAPH:': 1
# 'PA AND LATERAL CHEST FILMS CLINICAL INDICATION:': 1
# 'O ASPIRATION IMPRESSION:': 1
# 'TIA TIA TECHNIQUE:': 1
# 'SUPINE PORTABLE FRONTAL VIEW OF THE CHEST:': 1
# 'AML TECHNIQUE:': 1
# 'CCXR:': 1
# 'RML PNA COMPARISON:': 1
# 'REMOVAL TECHNIQUE:': 1
# 'FRONTAL SUPINE PORTABLE VIEW OF THE CHEST:': 1
# 'UPRIGHT AP VIEW OF THE CHEST COMPARISON:': 1
# 'LATERAL VIEW OF THE CHEST:': 1
# 'TWO PORTABLE ERECT VIEWS OF THE CHEST:': 1
# 'AP UPRIGHT VIEWS OF THE CHEST DURING INSPIRATION AND EXPIRATION:': 1
# 'NEW ONSET OF DYSPENA IMPRESSION:': 1
# 'PA AND LATERAL CHEST RADIOGRAPHS PERFORMED IN COMPARISON TO :': 1
# 'QF IMPRESSION:': 1
# 'ACEMENT IMPRESSION:': 1
# 'SVC  CHEST RADIOGRAPH INDICATION:': 1
# 'ETT PLACEMENT COMPARISON:': 1
# 'R PTX R PTX IMPRESSION:': 1
# 'S IMPRESSION:': 1
# 'ANY EVIDENCE OF ACUTE BLEED COMPARISON:': 1
# 'CHSET RADIOGRAPH INDICATION:': 1
# 'CXR POD IMPRESSION:': 1
# 'BEDSIDE AP RADIOGRAPH OF THE CHEST:': 1
# 'ALL FINDINGS:': 1
# 'SINGLE PORTABLE AP RADIOGRAPH OF THE CHEST COMPARISON:': 1
# 'IMPRESION:': 1
# 'SEVERE MR IMPRESSION:': 1
# 'SUPINE AP PORTABLE CHEST RADIOGRAPH:': 1
# 'NO PRIOR FINDINGS:': 1
# 'ASSESS FOR TUBERCULOSIS INFECTION IMPRESSION:': 1
# 'SUPINE PORTABLE CHEST RADIOGRAPHS:': 1
# 'VQ CXR COMPARISON:': 1
# 'E TECHNIQUE:': 1
# 'DAH IMPRESSION:': 1
# 'EXAMS COMPARISON:': 1
# 'ABNORMAL CT SCAN IMPRESSION:': 1
# 'HEPARIN POWER PICC IMPRESSION:': 1
# 'PORTABLE AP UPRIGHT RADIOGRAPH OF THE CHEST:': 1
# 'ASSESS FOR INFILTRATE COMPARISON:': 1
# 'PJP COMPARISON:': 1
# 'AP AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:': 1
# 'ERCP COMPARISON:': 1
# 'NO DEFINITE LARGE PNEUMOTHORAX IN THIS PORTABLE CHEST RADIOGRAPH  EXAMINATION:': 1
# 'PNTX PNTX IMPRESSION:': 1
# 'DX IS WORSENING EDEMA COMPARISON:': 1
# 'LVEF:': 1
# 'CRACKLES BILATERALLY IMPRESSION:': 1
# 'ACUTE BRONCHITIS IMPRESSION:': 1
# 'VAP VAP TECHNIQUE:': 1
# 'POST INTUBATION POST INTUBATION POST INTUBATION IMPRESSION:': 1
# 'EVAL FOR FOLLOW UP IMPRESSION:': 1
# 'TPC IMPRESSION:': 1
# 'FA TECHNIQUE:': 1
# 'INGUINAL ABSCESS IMPRESSION:': 1
# 'ADDITIONAL CLINICAL HISTORY PROVIDED:': 1
# 'THIS STUDY WAS ALREADY PERFORMED TECHNIQUE:': 1
# 'LOW GRADE FEVER PAST HX IMPRESSION:': 1
# 'O PNEUMONIA AND PLS ASSESS POSITION OF NG TUBE IMPRESSION:': 1
# 'SAVR TECHNIQUE:': 1
# 'PA AND LATERAL CHEST AT HOURS HISTORY:': 1
# 'CHEST CT TWO VIEWS:': 1
# 'DDD TECHNIQUE:': 1
# 'COUGH SOB IMPRESSION:': 1
# 'DEEMBER HISTORY:': 1
# 'PA AND LATERAL FILMS OF THE CHEST:': 1
# 'PORTABLE CHEST FILM ON AT CLINICAL INDICATION:': 1
# 'LATERAL CHEST COMPARISON:': 1
# 'THE BONES IT THAT WAY IT COULD JUST SIGN A FETUS:': 1
# 'EVALUATE BLEEDING TECHNIQUE:': 1
# 'XRAY COMPARISON:': 1
# 'TINGED SPUTUM IMPRESSION:': 1
# 'S NOTIFICATION:': 1
# 'RAY PLEASE TECHNIQUE:': 1
# 'VQ SCAN IMPRESSION:': 1
# 'ESRD TECHNIQUE:': 1
# 'PORTABLE CHEST WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DATE FINDINGS:': 1
# 'MR FINDINGS:': 1
# 'RAY DATED FINDINGS:': 1
# 'MS WITH LOW GRADE FEVER AND PRODUCTIVE COUGH IMPRESSION:': 1
# 'CHEST AND ABDOMINAL RADIOGRAPHS INDICATION:': 1
# 'ASPIRATION AND DOBHOFF PALCEMENT IMPRESSION:': 1
# 'PA AND LATERAL VIEWS CHEST:': 1
# 'REMOVAL STERNAL HARDWARE CHEST CLOSURE COMPARISON:': 1
# 'THE DICTATION SHOULD HAVE READ:': 1
# 'PORTABLE PA CHEST RADIOGRAPH:': 1
# 'CXR TWO IMAGES HISTORY:': 1
# 'UPRIGHT TECHNIQUE:': 1
# 'O ASTHMA FLARE VS ABNORMALITY IMPRESSION:': 1
# 'NAFLD TECHNIQUE:': 1
# 'LUE PICC TECHNIQUE:': 1
# 'CT AND CHEST CT FINDINGS:': 1
# 'PLEASE TAKE AT IMPRESSION:': 1
# 'PLEASE CHECK AT COMPARISON:': 1
# 'TWO VIEW CHEST OF COMPARISON:': 1
# 'SINGLE AP ERECT PORTABLE VIEW OF THE CHEST:': 1
# 'SDA COMPARISON:': 1
# 'COUGH PNA FINDINGS:': 1
# 'COMPARISON IS MADE WITH PRIOR STUDIES INCLUDING IMPRESSION:': 1
# 'PLEASE NOTE PATIENT ALSO HAS THE MEDICAL RECORD NUMBER AND CLINICAL INFORMATION:': 1
# 'UPRIGHT AP AND LATERAL CHEST RADIOGRAPH:': 1
# 'UPRIGHT FRONTAL AND LATERAL VIEWS OF THE CHEST:': 1
# 'PA TECHNIQUE:': 1
# 'NO EARLIER IMPRESSION:': 1
# 'PM HISTORY:': 1
# 'R IJ CVL IMPRESSION:': 1
# 'HA COMPARISON:': 1
# 'UPRIGHT COMPARISON:': 1
# 'VWS FINDINGS:': 1
# 'POD EXAMINATION:': 1
# 'P REPAIR PLACEMENT OF LINES AND TUBES COMPARISON:': 1
# 'HISTORY OF PRESENT ILLNESS:': 1
# 'FRONTAL AND LATERAL VIEWS OF CHEST:': 1
# 'CPR TECHNIQUE:': 1
# 'ACUTE PROCESS IMPRESSION:': 1
# 'DVT CXR:': 1
# 'COUGH FOR WEEKS IMPRESSION:': 1
# 'X TECHNIQUE:': 1
# 'APC FINDINGS:': 1
# 'CT CHEST FROM AND CHEST RADIOGRAPH FROM THE IMPRESSION:': 1
# 'MEDIASTINAL:': 1
# 'BI TECHNIQUE:': 1
# 'RAY AND CHEST CT FROM AN OUTSIDE INSTITUTION FINDINGS:': 1
# 'WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DAY FINDINGS:': 1
# 'CHEST RADIOGRAPHL INDICATION:': 1
# 'PORTABLE CHEST PICC PLACEMENT INDICATION:': 1
# 'NGT POSITION NCHECK IMPRESSION:': 1
# 'REFERENCE MADE TO CHEST CT FROM FINDINGS:': 1
# 'UPRIGHT AP AND LATERAL VIEWS OF CHEST:': 1
# 'PLEASE IMPRESSION:': 1
# 'S HISTORY:': 1
# 'POST CHEMO TREATMENT COMPARISON:': 1
# 'OGT TUBE ADVANCEMENT POSITION TECHNIQUE:': 1
# 'LAD LAD LAD IMPRESSION:': 1
# 'FRONTAL LATERAL CHEST RADIOGRAPH:': 1
# 'PA AND LATERAL VIEWS OF THE CHEST INDICATION:': 1
# 'A  SINGLE FRONTAL VIEW OF THE CHEST:': 1
# 'ETT AND OG PLACEMENT IMPRESSION:': 1
# 'WNC COMPARISON:': 1
# 'SBO  HISTORY:': 1
# 'CXR REPORT:': 1
# 'TBNA IMPRESSION:': 1
# 'BS IMPRESSION:': 1
# 'BC TECHNIQUE:': 1
# 'WEAKNESS COMPARISON:': 1
# 'CA PNA PNA COMPARISON:': 1
# 'PORTABLE AP FILM WAS OBTAINED COMPARISON:': 1
# 'II AVB TECHNIQUE:': 1
# 'GT IMPRESSION:': 1
# 'ACUTE RENAL FAILURE IMPRESSION:': 1
# 'RBBB COMPARISON:': 1
# 'COUGH ASSESS FOR INFILTRATE COMPARISON:': 1
# 'HPT IMPRESSION:': 1
# 'COUGH AND CHEST CONGESTION COMPARISON:': 1
# 'SDH COMPARISON:': 1
# 'PRX TECHNIQUE:': 1
# 'DAYS OF FEVER WITH COUGH AND SOB PRODUCTIVE DISCOLORED PHLEGM CALL WITH RESULTS AND FAX REPORT TO IMPRESSION:': 1
# 'SEPSIS CHEST:': 1
# 'CT  CHEST RADIOGRAPH INDICATION:': 1
# 'TWO VIEW ON HISTORY:': 1
# 'RAY ON ADDENDUM:': 1
# 'WITH MULTIPLE COMPARISON CHEST RADIOGRAPHS AND CT SCANS DATING BACK TO FINDINGS:': 1
# 'STAT XRAY STAT XRAY IMPRESSION:': 1
# 'ICP IMPRESSION:': 1
# 'AMS CT:': 1
# 'FINDINDGS:': 1
# 'PM CLINICAL INDICATION:': 1
# 'PORTABLE CHEST RADIOGRAPH WITH COMPARISON TO RADIOGRAPH OF ONE DAY EARLIER FINDINGS:': 1
# 'CHESTS RADIOGRAPH INDICATION:': 1
# 'PNA OR CHF TECHNIQUE:': 1
# 'DL PICC TECHNIQUE:': 1
# 'VT COMPARISON:': 1
# 'FINAL ADDENDUM HISTORY:': 1
# 'SCOLIOSIS FINDINGS:': 1
# 'SINGLE AP VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'SEMIERECT AP VIEW OF THE CHEST:': 1
# 'NASOGASTRIC FEEDING TUBE PASSES AT LEAST AS FAR AS THE DISTAL STOMACH NOTIFICATION:': 1
# 'R IMPRESSION:': 1
# 'RAY WITH COMPARISON RADIOGRAPH FINDINGS:': 1
# 'TWO IMAGES:': 1
# 'NGT TUBE PLACEMENT IMPRESSION:': 1
# 'LOCATION OF THE ET TUBE NG TUBE COMPARISON:': 1
# 'AT :': 1
# 'PLEASE CALL WITH WET READ TO BEEPER COMPARISON:': 1
# 'DOE SOB IMPRESSION:': 1
# 'OF COMPARISON:': 1
# 'IMPRSSION:': 1
# 'CVICU A COMPARISON:': 1
# 'SMOKER IMPRESSION:': 1
# 'ACCUTE BRONCHITIS IMPRESSION:': 1
# 'CEREBRAL EDEMA TECHNIQUE:': 1
# 'FRONTAL AND LATERAL VIEWS OF THE CHEST REASON FOR EXAM:': 1
# 'RU COMPARISON:': 1
# 'SUPINE AP:': 1
# 'ICP COMPARISON:': 1
# 'RFA TECHNIQUE:': 1
# 'CVID IMPRESSION:': 1
# 'TRALI TECHNIQUE:': 1
# 'DOE IMPRESSION:': 1
# 'FOLLOW UP TO PNA COMPARISON:': 1
# 'SINGLE FRONTAL AND LATERAL VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'FEVER SOB COUGH IMPRESSION:': 1
# 'MO IMPRESSION:': 1
# 'PORTABLE CHEST WITH NO PRIOR RADIOGRAPHS FOR COMPARISON FINDINGS:': 1
# 'POSITIVE PPD YEARS AGO COMPARISON:': 1
# 'IN FINDINGS:': 1
# 'EFFUSION IMPRESSION:': 1
# 'IMPRESSOIN:': 1
# 'O PNA EXAMINATION:': 1
# 'AND CHEST CT FROM FINDINGS:': 1
# 'PULMONARY EDEMA IMPRESSION:': 1
# 'L FM TRIGGER:': 1
# 'PA AND LATERAL VIEWS OF THE CHEST FINDINGS:': 1
# 'BKA IMPRESSION:': 1
# 'L SDH TECHNIQUE:': 1
# 'OMR:': 1
# 'REFERENCE FINDINGS:': 1
# 'RAY FROM AT FINDINGS:': 1
# 'PERICARIDAL EFFUSION EVALUATE FOR INTERVAL COMPARISON:': 1
# 'ACTIVE TB TECHNIQUE:': 1
# 'UNEXPLAINED RALES RT BASE COMPARISON:': 1
# 'EVAL FOR PRIMARY LUNG DISEASE TECHNIQUE:': 1
# 'TUBE PLACEMENT IMPRESSION:': 1
# 'RADIOGRAPHS OF THE CHEST AND RIBS HISTORY:': 1
# 'PA AND AP CHEST RADIOGRAPH:': 1
# 'ARDS:': 1
# 'ED EXAM:': 1
# 'PORTAL FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'PRIOR EXAM:': 1
# ...
# 'BGT TECHNIQUE:': 1
# 'PTA TECHNIQUE:': 1
# 'AP  COMPARISON:': 1
# 'O ICH TECHNIQUE:': 1
# 'LLB PNA IMPRESSION:': 1
# 'BPF COMPARISON:': 1
# 'ONGOING OR WORSENED PNEUMONIA COMPARISON:': 1
# 'PLAIN FILMS COMPARISON:': 1
# 'SUPINE AP VIEW OF THE CHEST COMPARISON:': 1
# 'DEDICATED VIEWS OF THE RIGHT RIBS:': 1
# 'COMPARISON WITH A CHEST CT FROM AS WELL AS A CHEST CT FROM CLINICAL HISTORY:': 1
# 'PERIPHERAL VASCULAR DISEASE IMPRESSION:': 1
# 'PM DOBHHOFF IN DISTAL ESOPHAGUS  PORTABLE CHEST RADIOGRAPH DATED COMPARISON:': 1
# 'IMPROVEMENT OR WORSENING IMPRESSION:': 1
# 'L LENI:': 1
# 'SINGLE AP RADIOGRAPH OF THE CHEST COMPARISON:': 1
# 'COUGH AND FEVER TECHNIQUE:': 1
# 'DISSECTION TECHNIQUE:': 1
# 'P CABG MORNING ROUND XRAY AT IMPRESSION:': 1
# 'CHEST SINGLE VIEW INDICATION:': 1
# 'WET READ TECHNIQUE:': 1
# 'SINGLE UPRIGHT PORTABLE VIEW OF THE CHEST:': 1
# 'CONLCUSION:': 1
# 'RT CHEST PAIN TECHNIQUE:': 1
# 'TECHNIQUE AND FINDINGS:': 1
# 'FINAL ADDENDUM ADDENDUM THIS REPORT SUPERSEDES THE EARLIER REPORT FOR THE STUDY OF AT HOURS:': 1
# 'THE IMPRESSION SHOULD READ:': 1
# 'PNTX IMPRESSION:': 1
# 'I FINDINGS:': 1
# 'R CVL TECHNIQUE:': 1
# 'CT CT COMPARISON:': 1
# 'CHEST PORTABLE AT CLINICAL INDICATION:': 1
# 'TOS TECHNIQUE:': 1
# 'PERSISTENT FEVER WITH COUGH COMPARISON:': 1
# 'AND CT CHEST FROM IMPRESSION:': 1
# 'RT POSTERIOR CHEST PAIN IMPRESSION:': 1
# 'IMMIGRATION CLEARANCE IMPRESSION:': 1
# 'O INFE CTIOUS PROCESS COMPARISON:': 1
# 'DC TECHNIQUE:': 1
# 'CP PTX COMPARISON:': 1
# 'ETT ETT PLACEMENT ETT PLACEMENT IMPRESSION:': 1
# 'WET READ PLS IMPRESSION:': 1
# 'WITH COMPARISON RADIOGRAPH OF TWO DAYS EARLIER FINDINGS:': 1
# 'CNS LYMPHOMA IMPRESSION:': 1
# 'MI IMPRESSION:': 1
# 'BIBASILAR OPACITIES ANNUAL AND MIGHT POTENTIALLY REPRESENT ATELECTASIS BUT INFECTIOUS PROCESS GIVING THE RELATIVELY LARGE SIZE OF DOSE:': 1
# 'PLEURISY IMPRESSION:': 1
# 'MM IMPRESSION:': 1
# 'CEREBELLAR ICH IMPRESSION:': 1
# 'FRONTAL AND LATERAL VIEWS OF THE CHEST IN EXPIRATION:': 1
# 'PORTALBLE AP CHEST RADIOGRAPH:': 1
# 'PE M IMPRESSION:': 1
# 'F IMPRESSION:': 1
# 'MVA COMPARISON:': 1
# 'PORTABLE AP UPRIGHT CHEST RADIOGRAPHS:': 1
# 'GBM COMPARISON:': 1
# 'FOR VQ SCAN IMPRESSION:': 1
# 'POTABLE CHEST FROM AT CLINICAL INDICATION:': 1
# 'RML PNA RML PNA COMPARISON:': 1
# 'RECOMMEDATIONS:': 1
# 'LEFT BASILAR PNA IMPRESSION:': 1
# 'HHNK TECHNIQUE:': 1
# 'RAY OF WITH COMPARISON RADIOGRAPH OF EARLIER THE SAME DAY FINDINGS:': 1
# 'L DVT TECHNIQUE:': 1
# 'ABNOR COMPARISON:': 1
# 'O RLL PNEUMONIA IMPRESSION:': 1
# 'CHEST RADIOGRAPHS SINCE MOST RECENTLY AND :': 1
# 'SOB AND ORTHOPNEA IMPRESSION:': 1
# 'MVR TECHNIQUE:': 1
# 'NOTFICATIONS:': 1
# 'O VAP TECHNIQUE:': 1
# 'CT CONCLUSION:': 1
# 'RADIOGRAPH FINDINGS:': 1
# 'AT IMPRESSION:': 1
# 'FTT TECHNIQUE:': 1
# 'M MVC TECHNIQUE:': 1
# 'TECHIQUE:': 1
# 'ETT CXR CXR IMPRESSION:': 1
# 'OSH PNA TECHNIQUE:': 1
# 'CODE IMPRESSION:': 1
# 'PULMONARY VASCULAR CONGESTION IMPRESSION:': 1
# 'PORTABLE AP CHEST XRAY INDICATION:': 1
# 'COCLUSION:': 1
# 'RAY ON HISTORY:': 1
# 'NO CURRENT SYMPTOMS PER PT HX SMOKER IMPRESSION:': 1
# 'UPRIGHT PORTABLE COMPARISON:': 1
# 'OSA IMPRESSION:': 1
# 'PLEASE OBTAIN DURING AM ROUNDS ON IMPRESSION:': 1
# 'PNEUMONIA TECHNIQUE:': 1
# 'ECMO IMPRESSION:': 1
# 'SUPINE CHEST RADIOGRAPH HISTORY:': 1
# 'AP GRID CHEST IMPRESSION:': 1
# 'STUDY PA AND LATERAL CHEST RADIOGRAPH INDICATION:': 1
# 'PAGER TECHNIQUE:': 1
# 'CHEST AP PORTABLE:': 1
# 'I D:': 1
# 'PORTABLE UPRIGHT CHEST RADIOGRAPH HISTORY:': 1
# 'CHEST ETIOLOGY TECHNIQUE:': 1
# 'RML EXAMINATION:': 1
# 'MOST RECENTLY IMPRESSION:': 1
# 'LLQ CXR:': 1
# 'PLEASE ALSO OBTAIN LORDOTIC VIEW COMPARISON:': 1
# 'RAY WITH COMPARISON CHEST RADIOGRAPH OF EARLIER THE SAME DATE FINDINGS:': 1
# 'NECK SOFT TISSUES INDICATION:': 1
# 'PORTABLE AP CHEST FILM ON AT CLINICAL INDICATION:': 1
# 'IJ CVL TECHNIQUE:': 1
# 'SOB PE COMPARISON:': 1
# 'O PNA PNA TECHNIQUE:': 1
# 'COMAPRISON:': 1
# 'HOURS ON HISTORY:': 1
# 'PATIENT WITH HYPOXIA IMPRESSION:': 1
# 'CXRCTPA:': 1
# 'FINAL ADDENDUM ADDENDUM CORRECTION:': 1
# 'IABNP COMPARISON:': 1
# 'FINDOINGS:': 1
# 'IABP IABP IABP IMPRESSION:': 1
# 'PLEASE DO CXR FOR IP MONITORING PURPOSES PLEASE DO CXR FOR IP MONITORING PURPOSES COMPARISON:': 1
# 'ALL THROUGH IMPRESSION:': 1
# 'TB EXAMINATION:': 1
# 'PORTABLE CHEST FILM CLINICAL INDICATION:': 1
# 'UPRIGHT PA AND LATERAL VIEWS THE CHEST:': 1
# 'FINAL ADDENDUM ADDENDUM COMPARISON:': 1
# 'POSSIBLE MILD ASTHMA EXACERBATION AND EXAMINE CARDIAC SILOUETTE COMPARISON:': 1
# 'CHANGE IN LUNG STATUS IMPRESSION:': 1
# 'WBC EXAMINATION:': 1
# 'CHEST X RAY INDICATION:': 1
# 'ATELECTASIS IMPRESSION:': 1
# 'FINAL ADDENDUM ADDENDUM CHEST RADIOGRAPHS HISTORY:': 1
# 'CHESET RADIOGRAPH INDICATION:': 1
# 'CTX COMPARISON:': 1
# 'PND TECHNIQUE:': 1
# 'PRE MRI SCREENING IMPRESSION:': 1
# 'SINGLE AP RADIOGRAPHS:': 1
# 'ERCP CXR:': 1
# 'CBD TECHNIQUE:': 1
# 'PLEASE PERFORM X IMPRESSION:': 1
# 'SINGLE SUPINE AP PORTABLE CHEST RADIOGRAPH:': 1
# 'PORTABLE VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'ECHO COMPARISON:': 1
# 'KIDNEY TRANSPLANT EVAL CVL PLACEMENT EVAL CVL PLACEMENT IMPRESSION:': 1
# 'CHF COPD TECHNIQUE:': 1
# 'PAC IMPRESSION:': 1
# 'PM :': 1
# 'CLINICAL HISTORY PRE OP COMPARISON:': 1
# 'CVL CVL COMPARISON:': 1
# 'O MASS OR INFILTRATE IMPRESSION:': 1
# 'GG TECHNIQUE:': 1
# 'UP FINDINGS:': 1
# 'AP UPRIGHT PORTABLE CHEST:': 1
# 'COUGH RLL PNEUMONIA COMPARISON:': 1
# 'CHEST PERFORMED ON COMPARISON:': 1
# 'PORTABLE CHEST WITH COMPARISON RADIOGRAPH OF ONE DAY EARLIER FINDINGS:': 1
# 'ERECT AND LATERAL CHEST RADIOGRAPH:': 1
# 'FLUID IMPRESSION:': 1
# 'AMS PNA COMPARISON:': 1
# 'PLEASE MOVE TELE BOX TO SIDE BEFORE TAKING TECHNIQUE:': 1
# 'SINGLE FRONTAL PORTABLE SUPINE VIEW OF THE CHEST:': 1
# 'PREOP  COMPARISON:': 1
# 'EVAL FOR INTERVAL CHANGES IMPRESSION:': 1
# 'COUGH CHEST PAIN IMPRESSION:': 1
# 'O LUNG LESION IMPRESSION:': 1
# 'ASCVD COMPARISON:': 1
# 'FINAL ADDENDUM NOTE:': 1
# 'EVALUATE INFILTRATE VS FIBROSIS IMPRESSION:': 1
# 'NEW PLEURAL EFFUSION COMPARISON:': 1
# 'HYPERINFLATION IMPRESSION:': 1
# 'SOB CXR:': 1
# 'LENI RLE:': 1
# 'PCI TECHNIQUE:': 1
# 'CTH:': 1
# 'SUPINE PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:': 1
# 'COUGH FEVER IMPRESSION:': 1
# 'RRT COMPARISON:': 1
# 'CHEST ON CHEST HISTORY:': 1
# 'A  SINGLE PORTABLE VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'DX DYSPNEA IMPRESSION:': 1
# 'RVR COMPARISON:': 1
# 'CHEST RADIOGRAPHS NONE THROUGH IMPRESSION:': 1
# 'COMPARED TO CHEST RADIOGRAPHS MOST RECENTLY :': 1
# 'O CHEST MASS COMPARISON:': 1
# 'PORTABLE FRONTAL VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'CODE CODE TECHNIQUE:': 1
# 'CHEST PORTABLE VIEW:': 1
# 'FRONTAL LATERAL VIEWS CHEST:': 1
# 'RECOMMMENDATIONS:': 1
# 'U PRBC TECHNIQUE:': 1
# 'CHF:': 1
# 'AP RADIOGRAPH OF THE CHEST:': 1
# 'PA AND LATERAL RADIOGRAPH:': 1
# 'CHILLS HX PNEUMONIA COMPARISON:': 1
# 'AMS PNA PNA IMPRESSION:': 1
# 'KUB COMPARISON:': 1
# 'SINGLE PA VIEW OF THE CHEST:': 1
# 'CHFWAITING FOR WET READ BEFORE PATIENT DISPOSITION COMPARISON:': 1
# 'RAY AS WELL AS FINDINGS:': 1
# 'PERSISTENT COUGH FOR MOS EVAL FOR PNA IMPRESSION:': 1
# 'PA AND LATERAL CHEST EXAM OF COMPARISON:': 1
# 'SKIN FOLDS IMPRESSION:': 1
# 'R IVC CVL R IVC CVL TECHNIQUE:': 1
# 'NEOB IMPRESSION:': 1
# 'FINAL ADDENDUM ADDENDUM HISTORY:': 1
# 'OSTEOMYELITIS L STUMP COMPARISON:': 1
# 'COMPARED TO PRIOR CHEST RADIOGRAPHS THROUGH :': 1
# 'SINGLE VIEW  COMPARISON:': 1
# 'PA AND LATERAL CHEST RADIOGRAPH CLINICAL HISTORY:': 1
# 'III CKD TECHNIQUE:': 1
# 'BOTH PROGRESSED SINCE :': 1
# 'U AFTER PNEUMONIA IN IMPRESSION:': 1
# 'NJT IMPRESSION:': 1
# 'TWO VIES OF THE CHEST:': 1
# 'AP CHEST CLINICAL HISTORY:': 1
# 'LLL FINDINGS:': 1
# 'REASON FOR COUGH TECHNIQUE:': 1
# 'SOB STAT STAT IMPRESSION:': 1
# 'PA COMPARISON FILM:': 1
# 'RAY INDICATIONS:': 1
# 'PLEASE OBTAIN CXR AT TECHNIQUE:': 1
# 'L PNA TECHNIQUE:': 1
# 'FOUR VIEWS:': 1
# 'WITH COMPARISON STUDY OF FINDINGS:': 1
# 'PORTABLE UPRIGHT CHEST RADIOGRAPH CLINICAL HISTORY:': 1
# 'SINGLE AP VIEW OF THE CHEST INDICATION:': 1
# 'SVC  REASON FOR EXAMINATION:': 1
# 'PLEASE D IMPRESSION:': 1
# 'EDEMA IMPRESSION:': 1
# 'INTERVAL CHANGES INTERVAL CHANGES IMPRESSION:': 1
# 'ERECT AP PORTABLE VIEW OF THE CHEST:': 1
# 'TTP COMPARISON:': 1
# 'PHONE IMPRESSION:': 1
# 'CHEST FILM AT CLINICAL INDICATION:': 1
# 'CT ABDOMEN FINDINGS:': 1
# 'TRANSIENT ISCHEMIC ATTACK IMPRESSION:': 1
# 'AM CXR COMPARISON:': 1
# 'EVALUATE FOR INTERAL CHANGE IMPRESSION:': 1
# 'D IMPRESSION:': 1
# 'POST TAVR POST TAVR TECHNIQUE:': 1
# 'EVAL FOR CHF IMPRESSION:': 1
# 'AS WELL AS EARLIER STUDIES DATING BACK TO FINDINGS:': 1
# 'ELEVATED ALK PHOSE IMPRESSION:': 1
# 'TWO AP VIEWS OF THE CHEST:': 1
# 'AT HOURS COMPARISON:': 1
# 'PNA ETT COMPARISON:': 1
# 'A  CHEST RADIOGRAPH COMPARISON:': 1
# 'PLEASE OBTAIN PA AND LATERAL TECHNIQUE:': 1
# 'FINAL ADDENDUM ADDENDUM CHEST RADIOGRAPHS INDICATION:': 1
# 'AND TARGETED REVIEW OF CHEST CTA FROM FINDINGS:': 1
# 'ACUTE CHANGES IN HIS MENTAL STATUS INFILTRATION COMPARISON:': 1
# 'URI CHF IMPRESSION:': 1
# 'COMPARISIONS:': 1
# 'PA AND LATERAL VIEWS OF THE CHEST COMPARISON:': 1
# 'OR PTX PTX IMPRESSION:': 1
# 'PORTABLE CHEST REASON FOR EXAM:': 1
# 'FINAL ADDENDUM PLEASE NOTE:': 1
# 'KNEE FILMS ON HISTORY:': 1
# 'O PULMONARY DISEASE TECHNIQUE:': 1
# 'PORTABLE ABDOMEN INDICATION:': 1
# 'A PORTABLE AP CHEST FILM AT CLINICAL INDICATION:': 1
# 'EVAL PICC PLACEMENT IMPRESSION:': 1
# 'TWO PORTABLE FRONTAL RADIOGRAPHS:': 1
# 'SOB PTX TECHNIQUE:': 1
# 'BV ICD IMPRESSION:': 1
# 'PROCESS TECHNIQUE:': 1
# 'PNARUQ:': 1
# 'COUGH PNA TECHNIQUE:': 1
# 'PICC LINE COMPARISON:': 1
# 'BONE WINDOWS:': 1
# 'PLEASE PERFORM FIRST THING IN MOR COMPARISON:': 1
# 'SINGLE AP PORTABLE SUPINE VIEW:': 1
# 'HTX TECHNIQUE:': 1
# 'CXE IMPRESSION:': 1
# 'CXR AM TECHNIQUE:': 1
# 'PORTABLE AP RADIOGRAPH WAS OBTAINED COMPARISON:': 1
# 'CHEST RADIOGRAPHS CHEST RADIOGRAPHS HISTORY:': 1
# 'CT CHEST FINDINGS:': 1
# 'HEART SIZE AND MEDIASTINUM ARE UNREMARKABLE IMPRESSION:': 1
# 'ETT AND DOBHOFF PLACEMENT IMPRESSION:': 1
# 'HCV TECHNIQUE:': 1
# 'INGUINAL HERNIA RIGHT HERNIORRHAPHY INGUINAL WITH MESH RIGHT IMPRESSION:': 1
# 'ASSESS DOBHOFF TECHNIQUE:': 1
# 'NO PRIOR CHEST RADIOGRAPHS IMPRESSION:': 1
# 'LIJ TLC TECHNIQUE:': 1
# 'CHEST SINGLE COMPARISON:': 1
# 'PACER WIRE LOCATION COMPARISON:': 1
# 'NCHCT TECHNIQUE:': 1
# 'PRELIMINARY REPORT:': 1
# 'SEMI ERECT PORTABLE CHEST RADIOGRAPH:': 1
# 'FINAL ADDENDUM COMPARISON:': 1
# 'LATERAL AND DECUBITUS VIEWS OF THE CHEST:': 1
# 'R TPA IMPRESSION:': 1
# 'O PNEUMONIA VS ASTHMA EXACERBATION IMPRESSION:': 1
# 'DYSPNEA WET READ COMPARISON:': 1
# 'SICU IMPRESSION:': 1
# 'HTN COMPARISON:': 1
# 'PORTABLE AP CHEST FILMS AT CLINICAL INDICATION:': 1
# 'PLEASE READ THE REPORT AS FOLLOWING:': 1
# 'LATERAL CHEST FILMS:': 1
# 'MVR FAST TRACK EARLY EXTUBATION CARDIAC SURGERY TECHNIQUE:': 1
# 'FRONTAL RADIOGRAPH OF THE CHEST:': 1
# 'UPRIGHT CHEST RADIOGRAPH HISTORY:': 1
# 'U NO NEW SIGNS OR SYMPTOMS IMPRESSION:': 1
# 'CHST RADIOGRAPHS INDICATION:': 1
# 'REASON FOR FLARE IMPRESSION:': 1
# 'NG TUBE PLACEMENT IMPRESSION:': 1
# 'IMPERSSION:': 1
# 'CHEST OF HISTORY:': 1
# 'PLS DO AT IMPRESSION:': 1
# 'SINGLE PORTABLE AP RADIOGRAPH OF THE CHEST CLINICAL INDICATION:': 1
# 'HCAP COMPARISON:': 1
# 'MS PNA TECHNIQUE:': 1
# 'P INTUBATION PLACEMENT TECHNIQUE:': 1
# 'AICD COMPARISON:': 1
# 'PLEASE OBTAIN AT IMPRESSION:': 1
# 'OBTAIN FOR AM IMPRESSION:': 1
# 'P CABG COMPARISON:': 1
# 'CP CXR:': 1
# 'CHEST CT IMPRESSION:': 1
# 'ITT TECHNIQUE:': 1
# 'CVA:': 1
# 'PA EXAMINATION:': 1
# 'AP ERECT:': 1
# 'RIJ CVC IMPRESSION:': 1
# 'CRP COMPARISON:': 1
# 'FRONTAL AND LATERAL FRONTAL CHEST RADIOGRAPH:': 1
# 'SUPINE PORTABLE RADIOGRAPH:': 1
# 'FINDGINGS:': 1
# 'RIGHT:': 1
# 'RCC COMPARISON:': 1
# 'X IMPRESSION:': 1
# 'PAIN IMPRESSION:': 1
# 'ONE VIEW OF THE CHEST AND ABDOMEN:': 1
# 'RIB PAIN IMPRESSION:': 1
# 'PORTABLE AP SUPINE CHEST RADIOGRAPH:': 1
# 'PA AND LATERAL CHEST FROM CLINICAL INDICATION:': 1
# 'P VATS DECORT ON L EVAL CHEST TUBES IMPRESSION:': 1
# 'IN PACU IN PACU TECHNIQUE:': 1
# 'RIBS:': 1
# 'VQ COMPARISON:': 1
# 'FOUR VIEWS COMPARISON FILM:': 1
# 'PA AND LATERAL CHEST WITH COMPARISON RADIOGRAPH FINDINGS:': 1
# 'PERFORMED ON COMPARISON:': 1
# 'FEEDING TUBE INSERTION IMPRESSION:': 1
# 'EVAL FOR PNA TECHNIQUE:': 1
# 'O COPD IMPRESSION:': 1
# 'UPRIGHT PORTABLE CHEST RADIOGRAPH CLINICAL HISTORY:': 1
# 'BOOP COMPARISON:': 1
# 'COP IMPRESSION:': 1
# 'EVLUATE FOR OPACITIES IMPRESSION:': 1
# 'ACUTE SUBDURAL HEMATOMA IMPRESSION:': 1
# 'CRP TECHNIQUE:': 1
# 'AP CHEST MIDNIGHT HISTORY:': 1
# 'PNX PNX IMPRESSION:': 1
# 'EIGHT IMAGES:': 1
# 'PA AND LATERAL VIEW OF THE CHEST:': 1
# 'WG TECHNIQUE:': 1
# 'LUL INFILTRATE COPD ASSESS FOR INTERVAL CHANGES IMPRESSION:': 1
# 'STAT STAT IMPRESSION:': 1
# 'CHEST RADIOGRAH INDICATION:': 1
# 'M :': 1
# 'CTA FRONTAL AND LATERAL CHEST:': 1
# 'PEG COMPARISON:': 1
# 'ASSESS PLACEMENT IMPRESSION:': 1
# 'FEVER COUGH IMPRESSION:': 1
# 'PNEUMONIA COMPARISON:': 1
# 'FRONTAL SUPINE CHEST RADIOGRAPH:': 1
# 'CH IMPRESSION:': 1
# 'NSIP IMPRESSION:': 1
# 'SVC  SINGLE AP PORTABLE VIEW OF THE CHEST REASON FOR EXAM:': 1
# 'AAM IMPRESSION:': 1
# 'PICC LINE PLACEMENT TECHNIQUE:': 1
# 'PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH OF FINDINGS:': 1
# 'RT LOWER CHEST PAIN COMPARISON:': 1
# 'A PORTABLE CHEST FILM AT CLINICAL INDICATION:': 1
# 'PORTABLE CHEST WITH COMPARISON AND EARLIER RADIOGRAPHS AND CT DATING BETWEEN AND FINDINGS:': 1
# 'N FINDINGS:': 1
# 'RCU IMPRESSION:': 1
# 'CHEAT RADIOGRAPH INDICATION:': 1
# 'REMOVAL OF CHEST TUBES TECHNIQUE:': 1
# 'NEUROENDOCRINE TUMOR IMPRESSION:': 1
# 'CLL TECHNIQUE:': 1
# 'PULMONARY NODULES AND MDS TECHNIQUE:': 1
# 'CHEST CLINICAL HISTORY:': 1
# 'PORTABLE CHEST ON COMPARISON:': 1
# 'CHEST PA AND LATERAL HISTORY:': 1
# 'MUST BE SUPINE TECHNIQUE:': 1
# 'EXAM TO BE DONE APPROX ON THANKS IMPRESSION:': 1
# 'CHEST RADIOGRAPH EXAMINATION DATED COMPARISON:': 1
# 'AP AND LATERAL VIEWS OF THE CHEST INDICATION:': 1
# 'CHEST AT INDICATION:': 1
# 'NTT COMPARISON:': 1
# 'RAY :': 1
# 'PPD EXAMINATION:': 1
# 'FOSH TECHNIQUE:': 1
# 'ERECT PORTABLE AP CHEST:': 1
# 'CORD COMPRESSION IMPRESSION:': 1
# 'CHEST RADIOGRAPH CLINICAL INDICATION:': 1
# 'PA AND LATERAL CHEST WITH COMPARISON RADIOGRAPHS OF ONE DAY EARLIER FINDINGS:': 1
# 'RIGHT IJ COMPARISON:': 1
# 'ETT CVL IMPRESSION:': 1
# 'PORTABLE AP WITH THE PATIENT SEMI UPRIGHT COMPARISON:': 1
# 'PO TECHNIQUE:': 1
# 'REASON FOR INDICATION:': 1
# 'CE IMPRESSION:': 1
# 'EXAM COMPARISON:': 1
# 'SINGLE PORTABLE VIEW REASON FOR EXAM:': 1
# 'SINGLE PORTABLE AP VIEW COMPARISON:': 1
# 'MILD EDEMA HAS IMPROVED SINCE :': 1
# 'MR COMPARISON:': 1
# 'ETT NGT IMPRESSION:': 1
# 'LAT HISTORY:': 1
# 'PA AND LATERAL VIEWS OF THE CHEST REASON OF EXAM:': 1
# 'STEP XRAY IMPRESSION:': 1
# 'TWO PORTABLE VIEWS OF THE CHEST:': 1
# 'SINGLE AP UPRIGHT VIEW OF THE CHEST:': 1
# 'MVA ON IMPRESSION:': 1
# 'CHEST RADIOGRAPH PERFORMED PORTABLY ON COMPARISON:': 1
# 'C FINDINGS:': 1
# 'RR TECHNIQUE:': 1
# 'PEG TECHNIQUE:': 1
# 'CHECK LEFT SUBCLAVIAN LINE TIP IMPRESSION:': 1
# 'WPC TECHNIQUE:': 1
# 'TECHNIQUE :': 1
# 'C  HISTORY:': 1
# 'PM ON TECHNIQUE:': 1
# 'PORTABLE AP CHEST FROM AT CLINICAL INDICATION:': 1
# 'OK COMPARISON:': 1
# 'PORTABLE CHEST RADIOGRAPH ON COMPARISON:': 1
# 'CHEST PA AND LATERAL:': 1
# 'O SOB COMPARISON:': 1
# 'PLEASE DO IN MORNING IMPRESSION:': 1
# 'MIN AFTER DISCOVERY  EXAMINATION:': 1
# 'M ON HISTORY:': 1
# 'FLUID TECHNIQUE:': 1
# 'POSITION OF DOBHOFF IMPRESSION:': 1
# 'IIMPRESSION:': 1
# 'IT WITH WITH NOTIFICATION:': 1
# 'PA LATERAL VIEWS OF THE CHEST:': 1
# 'UTI SOB SOB IMPRESSION:': 1
# 'II FINDINGS:': 1
# 'CHF VS COPD EXACERBATION TECHNIQUE:': 1
# 'CHEST PORTABLE RADIOGRAPH CLINICAL HISTORY:': 1
# 'V COMPARISON:': 1
# 'INCREASED DYSPNEA IMPRESSION:': 1
# 'DHT TECHNIQUE:': 1
# 'STAT CXR STAT CXR IMPRESSION:': 1
# 'RFA IMPRESSION:': 1
# 'OG TUBE PLACEMENT IMPRESSION:': 1
# 'HILAR OR INFILTRATE HX ASTHMA COMPARISON:': 1
# 'PD TECHNIQUE:': 1
# 'CKD TECHNIQUE:': 1
# 'FEVER COMPARISON:': 1
# 'SINGLE AP PORTABLE VIEW CENTERED LOW:': 1
# 'FINAL ADDENDUM TYPE OF EXAMINATION:': 1
# 'RAYS FINDINGS:': 1
# 'ABDOMEN:': 1
# 'SOB CHF CHF COMPARISON:': 1
# 'PERSISTANT COUGH FOR WEEKS COMPARISON:': 1
# 'NEW EFFUSION IMPRESSION:': 1
# 'PORTABLE CHEST RADIOGRAPH FINDINGS:': 1
# 'AND FINDINGS:': 1
# 'UPRIGHT CHEST RADIOGRAPHS:': 1
# 'FINDNGS:': 1
# 'P EVD PLCMT PULM CHANCES IMPRESSION:': 1
# 'O ASPIR TECHNIQUE:': 1
# 'CHEST SUPINE:': 1
# 'NIPPV COMPARISON:': 1
# 'M IMPRESSION:': 1
# 'DM COMPARISON:': 1
# 'PA CHEST RADIOGRAPH INDICATION:': 1
# 'S NOTE:': 1
# 'PNA EVAL EVAL COMPARISON:': 1
# 'PMA TECHNIQUE:': 1
# 'AP SEMIERECT:': 1
# 'GPA TECHNIQUE:': 1
# 'MR:': 1
# 'PTX PTX TECHNIQUE:': 1
# 'LATERAL VIEW CHEST:': 1
# 'R LENI:': 1
# 'NGT PLACEMENT NGT PLACEMENT IMPRESSION:': 1
# 'ERECT AP COMPARISON:': 1
# 'PERSISTENT COUGH EXAMINATION:': 1
# 'UTI TECHNIQUE:': 1
# 'OK INDICATION:': 1
# 'AM CCU CXR AM CCU CXR COMPARISON:': 1
# 'PNA LLL PNA IMPRESSION:': 1
# 'RAY FROM AT MIN PAST MIDNIGHT FINDINGS:': 1
# 'MVR COMPARISON:': 1

# %% [markdown]
# # transform cleaned content to list of dict

# %%
def item_to_dict(item):
    key_value_pairs = []
    segments = re.split(r'([A-Z\s]+:)', item)
    for i in range(1, len(segments) - 1, 2):
        key_value_pairs.append({segments[i].strip(): segments[i + 1].strip()})
    return key_value_pairs

# %%
df['list_to_dict'] = df['cleaned_content'].apply(item_to_dict)

# %%
df['list_to_dict'][222000]
# Out:
# [{'INDICATION:': 'Hypoxic respiratory failure.'},
#  {'COMPARISON:': 'Chest radiograph from .'},
#  {'TECHNIQUE:': 'Frontal chest radiograph.'},
#  {'IMPRESSION:': 'A right PICC terminates at the upper SVC. The heart size remains normal. The hilar and mediastinal contours are unchanged. Postsurgical changes are again seen at the left apex. An ill-defined left basilar opacity is unchanged. There is no pneumothorax or pleural effusion.'}]

# %% [markdown]
# # updating each row based on values (should replace all the "True")

# %%
# Function to update the DataFrame based on the list of dictionaries
def update_columns(row, col_name, df):
    dicts = row[col_name]
    for d in dicts:
        key, value = list(d.items())[0]
        if key in df.columns:
            df.loc[row.name, key] = f'{key} {value}'

# %%
for index, row in df.iterrows():
    update_columns(row, 'list_to_dict', df)

# %%
df["INDICATION:"][0]
# Out:
# 'INDICATION: F with new onset ascites eval for infection'

# %%
df["TECHNIQUE:"][0]
# Out:
# 'TECHNIQUE: Chest PA and lateral'

# %%
df["COMPARISON:"][0]
# Out:
# 'COMPARISON: None.'

# %%
df["IMPRESSION:"][0]
# Out:
# 'IMPRESSION: No acute cardiopulmonary process.'

# %%
df['headers'][227832]
# Out:
# ['COMPARISON:', 'FINDINGS:']

# %%
df['cleaned_content'][227832]
# Out:
# 'COMPARISON: radiograph. FINDINGS: There has been interval extubation and improved lung volumes compared to the recent radiograph. Bibasilar atelectasis has nearly resolved with residual patchy atelectasis remaining in the right lower lobe and only minimal residual linear atelectasis in the left lower lobe. Apparent rightward deviation of the trachea is likely due to mild patient rotation and curvature of the spine, as there is no evidence of a discrete paratracheal mass on recent neck CTA of . Cardiac silhouette is stable in size. No pleural effusion or pneumothorax.'

# %%
df['content'][227832]
# Out:
# '                                 FINAL REPORT\n PORTABLE CHEST OF ___\n \n COMPARISON:  ___ radiograph.\n \n FINDINGS:  There has been interval extubation and improved lung volumes\n compared to the recent radiograph.  Bibasilar atelectasis has nearly resolved\n with residual patchy atelectasis remaining in the right lower lobe and only\n minimal residual linear atelectasis in the left lower lobe.  Apparent\n rightward deviation of the trachea is likely due to mild patient rotation and\n curvature of the spine, as there is no evidence of a discrete paratracheal\n mass on recent neck CTA of ___.  Cardiac silhouette is stable in\n size.  No pleural effusion or pneumothorax.\n'

# %%
num_nans = df.isna().sum().sum()

print(num_nans)
# Out:
# 0

# %%
df
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content  \
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...
# ...                                                   ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...
# 227832  COMPARISON: radiograph. FINDINGS: There has be...
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834  INDICATION: -year-old female intubated for hea...
#
#                                                   headers  \
# 0       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 1       [EXAMINATION:, INDICATION:, TECHNIQUE:, COMPAR...
# 2       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# 3       [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 4       [EXAMINATION:, INDICATION:, COMPARISON:, FINDI...
# ...                                                   ...
# 227830  [INDICATION:, COMPARISON:, FINDINGS:, CONCLUSI...
# 227831  [INDICATION:, TECHNIQUE:, COMPARISON:, FINDING...
# 227832                           [COMPARISON:, FINDINGS:]
# 227833  [COMPARISON:, CLINICAL HISTORY:, FINDINGS:, IM...
# 227834  [INDICATION:, COMPARISON:, TECHNIQUE:, FINDING...
#
#        PA AND LATERAL HISTORY: PORTABLE CHEST RADIOGRAPH DATED COMPARISON:  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                                         ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST FILM AT INDICATION: FINAL ADDENDUM HISTORY:  ...  \
# 0                                                                        ...
# 1                                                                        ...
# 2                                                                        ...
# 3                                                                        ...
# 4                                                                        ...
# ...                                         ...                     ...  ...
# 227830                                                                   ...
# 227831                                                                   ...
# 227832                                                                   ...
# 227833                                                                   ...
# 227834                                                                   ...
#
#        CHEST RADIOGRAPHS PERFORMED ON COMPARISON: CHEST OF HISTORY:  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...               ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        CHEST RADIOGRAPH INDICATIONS: CHEST TWO VIEWS INDICATION:  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...                         ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        AP CHEST ON HISTORY: PA AND LATERAL CHEST CLINICAL INDICATION:  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                                       ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST ON HISTORY:  \
# 0
# 1
# 2
# 3
# 4
# ...                                 ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        AP UPRIGHT AND LATERAL VIEW OF THE CHEST PERFORMED ON COMPARISON:  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#        PA AND LATERAL CHEST OF WITH COMPARISON RADIOGRAPH FINDINGS:  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 227830
# 227831
# 227832
# 227833
# 227834
#
#                                              list_to_dict
# 0       [{'EXAMINATION:': 'CHEST (PA AND LAT)'}, {'IND...
# 1       [{'EXAMINATION:': 'CHEST (PA AND LAT)'}, {'IND...
# 2       [{'EXAMINATION:': 'CHEST (PORTABLE AP)'}, {'IN...
# 3       [{'INDICATION:': 'year old woman with cirrhosi...
# 4       [{'EXAMINATION:': 'CHEST (PA AND LAT)'}, {'IND...
# ...                                                   ...
# 227830  [{'INDICATION:': 'Patient with intubation, eva...
# 227831  [{'INDICATION:': '-year-old with chest pain.'}...
# 227832  [{'COMPARISON:': 'radiograph.'}, {'FINDINGS:':...
# 227833  [{'COMPARISON:': 'Prior chest radiograph from ...
# 227834  [{'INDICATION:': '-year-old female intubated f...
#
# [227835 rows x 313 columns]

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
non_nan_counts = df.count()

# columns with less than 10,000 non-nan values
columns_to_drop = non_nan_counts[non_nan_counts < 10000].index.tolist()

df = df.drop(columns_to_drop, axis=1)

# %%
df

# %%
import numpy as np

# %%
mask = df.notna().any()

def sort_cols(x):
    if x.dtype == 'object' and any(isinstance(val, list) for val in x):
        x = x.apply(lambda val: np.nan if isinstance(val, list) else val)
    return x.sort_values(na_position='last')

sorted_cols = df.loc[:, mask].apply(sort_cols)

print(sorted_cols)
# Out:
#         subject_id  study_id                               path  \
# 0         10000032  50414267  files/p10/p10000032/s50414267.txt
# 1         10000032  53189527  files/p10/p10000032/s53189527.txt
# 2         10000032  53911762  files/p10/p10000032/s53911762.txt
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 4         10000764  57375967  files/p10/p10000764/s57375967.txt
# ...            ...       ...                                ...
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227831    19999733  57132437  files/p19/p19999733/s57132437.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 0                                        FINAL REPORT\...
# 1                                        FINAL REPORT\...
# 2                                        FINAL REPORT\...
# 3                                        FINAL REPORT\...
# 4                                        FINAL REPORT\...
# ...                                                   ...
# 227830                                   FINAL REPORT\...
# 227831                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content  headers  \
# 0       EXAMINATION: CHEST (PA AND LAT) INDICATION: F ...      NaN
# 1       EXAMINATION: CHEST (PA AND LAT) INDICATION: Hi...      NaN
# 2       EXAMINATION: CHEST (PORTABLE AP) INDICATION: F...      NaN
# 3       INDICATION: year old woman with cirrhosis. TEC...      NaN
# 4       EXAMINATION: CHEST (PA AND LAT) INDICATION: M ...      NaN
# ...                                                   ...      ...
# 227830  INDICATION: Patient with intubation, evaluatio...      NaN
# 227831  INDICATION: -year-old with chest pain. TECHNIQ...      NaN
# 227832  COMPARISON: radiograph. FINDINGS: There has be...      NaN
# 227833  COMPARISON: Prior chest radiograph from earlie...      NaN
# 227834  INDICATION: -year-old female intubated for hea...      NaN
#
#                                                 FINDINGS:  \
# 0       FINDINGS: There is no focal consolidation, ple...
# 1       FINDINGS: The cardiac, mediastinal and hilar c...
# 2       FINDINGS: Single frontal view of the chest pro...
# 3       FINDINGS: The lungs are clear of focal consoli...
# 4       FINDINGS: PA and lateral views of the chest pr...
# ...                                                   ...
# 227830  FINDINGS: ET tube ends 4.7 cm above the carina...
# 227831  FINDINGS: The lungs are clear, and the cardiom...
# 227832  FINDINGS: There has been interval extubation a...
# 227833  FINDINGS: Portable supine AP view of the chest...
# 227834  FINDINGS: The ET tube terminates approximately...
#
#                                                TECHNIQUE:  \
# 0                         TECHNIQUE: Chest PA and lateral
# 1                         TECHNIQUE: Chest PA and lateral
# 2                                                     NaN
# 3       TECHNIQUE: Frontal chest radiographs were obta...
# 4                                                     NaN
# ...                                                   ...
# 227830                                                NaN
# 227831  TECHNIQUE: Frontal and lateral radiographs of ...
# 227832                                                NaN
# 227833                                                NaN
# 227834   TECHNIQUE: Single AP portable exam on the chest.
#
#                                               IMPRESSION:  \
# 0           IMPRESSION: No acute cardiopulmonary process.
# 1       IMPRESSION: No acute cardiopulmonary abnormality.
# 2             IMPRESSION: No acute intrathoracic process.
# 3           IMPRESSION: No acute cardiopulmonary process.
# 4       IMPRESSION: Focal consolidation at the left lu...
# ...                                                   ...
# 227830                                                NaN
# 227831       IMPRESSION: No acute cardiothoracic process.
# 227832                                                NaN
# 227833  IMPRESSION: Appropriately positioned ET and NG...
# 227834  IMPRESSION: Slight interval worsening of right...
#
#                                               COMPARISON:  \
# 0                                       COMPARISON: None.
# 1                                            COMPARISON:
# 2                            COMPARISON: Chest radiograph
# 3                    COMPARISON: Radiographs from , and .
# 4                                        COMPARISON: None
# ...                                                   ...
# 227830                                  COMPARISON: None.
# 227831                                  COMPARISON: None.
# 227832                            COMPARISON: radiograph.
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834               COMPARISON: Chest radiographs from .
#
#                                               INDICATION: WET READ:  \
# 0       INDICATION: F with new onset ascites eval for ...       NaN
# 1         INDICATION: History: F with shortness of breath       NaN
# 2                 INDICATION: F with cough acute process?       NaN
# 3              INDICATION: year old woman with cirrhosis.       NaN
# 4            INDICATION: M with hypoxia ?pna, aspiration.       NaN
# ...                                                   ...       ...
# 227830  INDICATION: Patient with intubation, evaluatio...       NaN
# 227831             INDICATION: -year-old with chest pain.       NaN
# 227832                                                NaN       NaN
# 227833                                                NaN       NaN
# 227834  INDICATION: -year-old female intubated for hea...       NaN
#
#        CHEST RADIOGRAPH INDICATION: HISTORY:  \
# 0                               NaN      NaN
# 1                               NaN      NaN
# 2                               NaN      NaN
# 3                               NaN      NaN
# 4                               NaN      NaN
# ...                             ...      ...
# 227830                          NaN      NaN
# 227831                          NaN      NaN
# 227832                          NaN      NaN
# 227833                          NaN      NaN
# 227834                          NaN      NaN
#
#                             EXAMINATION:  list_to_dict
# 0        EXAMINATION: CHEST (PA AND LAT)           NaN
# 1        EXAMINATION: CHEST (PA AND LAT)           NaN
# 2       EXAMINATION: CHEST (PORTABLE AP)           NaN
# 3                                    NaN           NaN
# 4        EXAMINATION: CHEST (PA AND LAT)           NaN
# ...                                  ...           ...
# 227830                               NaN           NaN
# 227831                               NaN           NaN
# 227832                               NaN           NaN
# 227833                               NaN           NaN
# 227834                               NaN           NaN
#
# [227835 rows x 16 columns]

# %%
sorted_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227835 entries, 0 to 227834
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   subject_id                    227835 non-null  int64
#  1   study_id                      227835 non-null  int64
#  2   path                          227835 non-null  object
#  3   content                       227835 non-null  object
#  4   cleaned_content               227834 non-null  object
#  5   FINDINGS:                     148838 non-null  object
#  6   TECHNIQUE:                    76649 non-null   object
#  7   IMPRESSION:                   184636 non-null  object
#  8   COMPARISON:                   158736 non-null  object
#  9   INDICATION:                   140768 non-null  object
#  10  WET READ:                     17556 non-null   object
#  11  CHEST RADIOGRAPH INDICATION:  10082 non-null   object
#  12  HISTORY:                      39471 non-null   object
#  13  EXAMINATION:                  93945 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 26.1+ MB

# %%
num_nans = sorted_cols.isna().sum().sum()

# %%
num_nans
# Out:
# 1179835

# %%
sorted_cols["cleaned_content"].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 227830    False
# 227831    False
# 227832    False
# 227833    False
# 227834    False
# Name: cleaned_content, Length: 227835, dtype: bool

# %%
sorted_cols.isna().sum()
# Out:
# subject_id                           0
# study_id                             0
# path                                 0
# content                              0
# cleaned_content                      1
# FINDINGS:                        78997
# TECHNIQUE:                      151186
# IMPRESSION:                      43199
# COMPARISON:                      69099
# INDICATION:                      87067
# WET READ:                       210279
# CHEST RADIOGRAPH INDICATION:    217753
# HISTORY:                        188364
# EXAMINATION:                    133890
# dtype: int64

# %%
empty_cleaned_content_rows = sorted_cols[sorted_cols['cleaned_content'].isnull()]
print(empty_cleaned_content_rows)
# Out:
#         subject_id  study_id                               path  \
# 101213    14463099  54168089  files/p14/p14463099/s54168089.txt
#
#                                                 content cleaned_content  \
# 101213                                   FINAL REPORT\n             NaN
#
#        FINDINGS: TECHNIQUE: IMPRESSION: COMPARISON: INDICATION: WET READ:  \
# 101213       NaN        NaN         NaN         NaN         NaN       NaN
#
#        CHEST RADIOGRAPH INDICATION: HISTORY: EXAMINATION:
# 101213                          NaN      NaN          NaN

# %%
sorted_cols.dropna(subset=['cleaned_content'], inplace=True)

# %%
sorted_cols = sorted_cols.drop(['list_to_dict', 'headers'], axis=1)

# %%
sorted_cols["WET READ:"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 227830    NaN
# 227831    NaN
# 227832    NaN
# 227833    NaN
# 227834    NaN
# Name: WET READ:, Length: 227835, dtype: object

# %%
non_null_cleaned_content_rows = sorted_cols[sorted_cols['WET READ:'].notnull()]

# %%
non_null_cleaned_content_rows
# Out:
#         subject_id  study_id                               path  \
# 19        10000980  58206436  files/p10/p10000980/s58206436.txt
# 28        10001217  58913004  files/p10/p10001217/s58913004.txt
# 32        10001401  56534136  files/p10/p10001401/s56534136.txt
# 51        10001884  55333410  files/p10/p10001884/s55333410.txt
# 90        10002428  56597576  files/p10/p10002428/s56597576.txt
# ...            ...       ...                                ...
# 227714    19997367  52358840  files/p19/p19997367/s52358840.txt
# 227720    19997367  52790106  files/p19/p19997367/s52790106.txt
# 227749    19997367  56627054  files/p19/p19997367/s56627054.txt
# 227781    19997911  58942262  files/p19/p19997911/s58942262.txt
# 227822    19999287  50574077  files/p19/p19999287/s50574077.txt
#
#                                                   content  \
# 19       WET READ: ___ ___ ___ 6:47 AM\n  1. New mild ...
# 28       WET READ: ___ ___ ___ 11:18 PM\n  It is diffi...
# 32       WET READ: ___ ___ ___ 6:21 AM\n  \n  An enter...
# 51       WET READ: ___ ___ ___ 4:36 PM\n  No acute car...
# 90       WET READ: ___ ___ ___ 9:42 AM\n  LEFT PICC TI...
# ...                                                   ...
# 227714   WET READ: ___ ___ ___ 9:04 PM\n  Fluid seems ...
# 227720   WET READ: ___ ___ ___ 7:42 AM\n  \n  \n  Incr...
# 227749   WET READ: ___ ___ ___ 9:20 PM\n  Compared to ...
# 227781   WET READ: ___ ___ ___ 8:13 PM\n  NG tube tip ...
# 227822   WET READ: ___ ___ ___ 9:36 AM\n  Substantial ...
#
#                                           cleaned_content  \
# 19      WET READ: 6:47 AM 1. New mild pulmonary edema ...
# 28      WET READ: 11:18 PM It is difficult to determin...
# 32      WET READ: 6:21 AM An enteric tube courses belo...
# 51      WET READ: 4:36 PM No acute cardiopulmonary abn...
# 90      WET READ: 9:42 AM LEFT PICC TIP PROJECTS OVER ...
# ...                                                   ...
# 227714  WET READ: 9:04 PM Fluid seems to be reaccumula...
# 227720  WET READ: 7:42 AM Increasing interstitial mark...
# 227749  WET READ: 9:20 PM Compared to the prior radiog...
# 227781  WET READ: 8:13 PM NG tube tip terminates in th...
# 227822  WET READ: 9:36 AM Substantial progression, wit...
#
#                                                 FINDINGS:  \
# 19      FINDINGS: In comparison to study performed on ...
# 28      FINDINGS: As compared to the previous radiogra...
# 32      FINDINGS: The right costophrenic angle is not ...
# 51      FINDINGS: PA and lateral views the chest provi...
# 90      FINDINGS: Comparison is made to previous study...
# ...                                                   ...
# 227714  FINDINGS: As compared to the previous image, t...
# 227720                                                NaN
# 227749                                                NaN
# 227781                                                NaN
# 227822                                                NaN
#
#                                                TECHNIQUE:  \
# 19      TECHNIQUE: Single portable upright frontal che...
# 28                                                    NaN
# 32                              TECHNIQUE: Single AP view
# 51                        TECHNIQUE: Chest PA and lateral
# 90                                                    NaN
# ...                                                   ...
# 227714                                                NaN
# 227720                         TECHNIQUE: Chest two views
# 227749                                                NaN
# 227781                                                NaN
# 227822                                                NaN
#
#                                               IMPRESSION:  \
# 19      IMPRESSION: 1. New mild pulmonary edema with p...
# 28                                                    NaN
# 32      IMPRESSION: An enteric tube courses below the ...
# 51      IMPRESSION: No acute findings. Top-normal hear...
# 90                                                    NaN
# ...                                                   ...
# 227714                                                NaN
# 227720  IMPRESSION: Increasing interstitial markings f...
# 227749  IMPRESSION: IN COMPARISON WITH THE EARLIER STU...
# 227781  IMPRESSION: Comparison to , 10:12. The tip of ...
# 227822  IMPRESSION: As compared to the previous examin...
#
#                                              COMPARISON:  \
# 19       COMPARISON: chest radiograph. chest radiograph.
# 28                                         COMPARISON: .
# 32      COMPARISON: Chest radiograph from the same date.
# 51      COMPARISON: Chest radiograph and chest CT from .
# 90                                                   NaN
# ...                                                  ...
# 227714                                     COMPARISON: .
# 227720                                      COMPARISON:
# 227749                                               NaN
# 227781                                               NaN
# 227822                                      COMPARISON:
#
#                                               INDICATION:  \
# 19      INDICATION: F with wheezing and dyspnea. Asses...
# 28                                                    NaN
# 32      INDICATION: History: F with SBO s/p NG*** WARN...
# 51      INDICATION: y.o. woman, multiple medical probl...
# 90                                                    NaN
# ...                                                   ...
# 227714  INDICATION: Evaluation for pneumothorax. Statu...
# 227720  INDICATION: year old woman with complicated pa...
# 227749  INDICATION: year old woman with chest tube eff...
# 227781  INDICATION: year old woman s/p NGT placement P...
# 227822  INDICATION: known SCC presenting with dyspnea ...
#
#                                                 WET READ:  \
# 19      WET READ: 6:47 AM 1. New mild pulmonary edema ...
# 28      WET READ: 11:18 PM It is difficult to determin...
# 32      WET READ: 6:21 AM An enteric tube courses belo...
# 51      WET READ: 4:36 PM No acute cardiopulmonary abn...
# 90      WET READ: 9:42 AM LEFT PICC TIP PROJECTS OVER ...
# ...                                                   ...
# 227714  WET READ: 9:04 PM Fluid seems to be reaccumula...
# 227720  WET READ: 7:42 AM Increasing interstitial mark...
# 227749  WET READ: 9:20 PM Compared to the prior radiog...
# 227781  WET READ: 8:13 PM NG tube tip terminates in th...
# 227822  WET READ: 9:36 AM Substantial progression, wit...
#
#                              CHEST RADIOGRAPH INDICATION: HISTORY:  \
# 19                                                    NaN      NaN
# 28      CHEST RADIOGRAPH INDICATION: PICC line placement.      NaN
# 32                                                    NaN      NaN
# 51                                                    NaN      NaN
# 90                                                    NaN      NaN
# ...                                                   ...      ...
# 227714                                                NaN      NaN
# 227720                                                NaN      NaN
# 227749                                                NaN      NaN
# 227781                                                NaN      NaN
# 227822                                                NaN      NaN
#
#                             EXAMINATION:
# 19        EXAMINATION: Chest radiograph.
# 28                                   NaN
# 32        EXAMINATION: Chest radiograph.
# 51         EXAMINATION: Chest radiograph
# 90                                   NaN
# ...                                  ...
# 227714                               NaN
# 227720   EXAMINATION: CHEST (PA AND LAT)
# 227749  EXAMINATION: CHEST (PORTABLE AP)
# 227781  EXAMINATION: CHEST (PORTABLE AP)
# 227822  EXAMINATION: CHEST (PORTABLE AP)
#
# [17556 rows x 14 columns]

# %% [markdown]
# # pull single image cases

# %%
df3 = pd.read_csv('/Users/katya/Downloads/cxr-record-list.csv')

# %%
value_counts2 = df3['study_id'].value_counts()

# %%
value_counts2
# Out:
# 54019440    11
# 50022785     9
# 54914372     8
# 50384171     8
# 54267739     8
#             ..
# 50158746     1
# 59249530     1
# 55895881     1
# 53492489     1
# 58971208     1
# Name: study_id, Length: 227835, dtype: int64

# %%
result2 = value_counts2[value_counts2 == 1]
result2
# Out:
# 56237305    1
# 54925626    1
# 55351970    1
# 57005648    1
# 50273602    1
#            ..
# 50158746    1
# 59249530    1
# 55895881    1
# 53492489    1
# 58971208    1
# Name: study_id, Length: 102675, dtype: int64

# %%
result3=df3['study_id'].nunique

# %%
result3
# Out:
# <bound method IndexOpsMixin.nunique of 0         50414267
# 1         50414267
# 2         53189527
# 3         53189527
# 4         53911762
#             ...
# 377105    57132437
# 377106    57132437
# 377107    55368167
# 377108    58621812
# 377109    58971208
# Name: study_id, Length: 377110, dtype: int64>

# %%
new_df = sorted_cols[sorted_cols['study_id'].isin(result2.index)]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102675 entries, 3 to 227834
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   subject_id                    102675 non-null  int64
#  1   study_id                      102675 non-null  int64
#  2   path                          102675 non-null  object
#  3   content                       102675 non-null  object
#  4   cleaned_content               102675 non-null  object
#  5   FINDINGS:                     52918 non-null   object
#  6   TECHNIQUE:                    24673 non-null   object
#  7   IMPRESSION:                   75268 non-null   object
#  8   COMPARISON:                   60257 non-null   object
#  9   INDICATION:                   63133 non-null   object
#  10  WET READ:                     9205 non-null    object
#  11  CHEST RADIOGRAPH INDICATION:  6351 non-null    object
#  12  HISTORY:                      15722 non-null   object
#  13  EXAMINATION:                  46559 non-null   object
# dtypes: int64(2), object(12)
# memory usage: 11.8+ MB

# %%
df_new = new_df.loc[:, new_df.count().sort_values(ascending=False).index]

# %%
df_new
# Out:
#         subject_id  study_id                               path  \
# 3         10000032  56699142  files/p10/p10000032/s56699142.txt
# 7         10000935  50578979  files/p10/p10000935/s50578979.txt
# 12        10000935  58219844  files/p10/p10000935/s58219844.txt
# 14        10000980  51967283  files/p10/p10000980/s51967283.txt
# 19        10000980  58206436  files/p10/p10000980/s58206436.txt
# ...            ...       ...                                ...
# 227829    19999442  58497551  files/p19/p19999442/s58497551.txt
# 227830    19999442  58708861  files/p19/p19999442/s58708861.txt
# 227832    19999987  55368167  files/p19/p19999987/s55368167.txt
# 227833    19999987  58621812  files/p19/p19999987/s58621812.txt
# 227834    19999987  58971208  files/p19/p19999987/s58971208.txt
#
#                                                   content  \
# 3                                        FINAL REPORT\...
# 7                                        FINAL REPORT\...
# 12                                       FINAL REPORT\...
# 14                                       FINAL REPORT\...
# 19       WET READ: ___ ___ ___ 6:47 AM\n  1. New mild ...
# ...                                                   ...
# 227829                                   FINAL REPORT\...
# 227830                                   FINAL REPORT\...
# 227832                                   FINAL REPORT\...
# 227833                                   FINAL REPORT\...
# 227834                                   FINAL REPORT\...
#
#                                           cleaned_content  \
# 3       INDICATION: year old woman with cirrhosis. TEC...
# 7       HISTORY: Leukocytosis, low-grade temperature, ...
# 12      HISTORY: Dyspnea and history of lung cancer. T...
# 14      INDICATION: -year-old female with shortness of...
# 19      WET READ: 6:47 AM 1. New mild pulmonary edema ...
# ...                                                   ...
# 227829  REASON FOR EXAMINATION: Aspiration suspected, ...
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227832  COMPARISON: radiograph. FINDINGS: There has be...
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834  INDICATION: -year-old female intubated for hea...
#
#                                               IMPRESSION:  \
# 3           IMPRESSION: No acute cardiopulmonary process.
# 7       IMPRESSION: 1. Low lung volumes and mild pulmo...
# 12      IMPRESSION: Innumerable pulmonary metastases. ...
# 14      IMPRESSION: Right upper lobe pneumonia or mass...
# 19      IMPRESSION: 1. New mild pulmonary edema with p...
# ...                                                   ...
# 227829                                                NaN
# 227830                                                NaN
# 227832                                                NaN
# 227833  IMPRESSION: Appropriately positioned ET and NG...
# 227834  IMPRESSION: Slight interval worsening of right...
#
#                                               INDICATION:  \
# 3              INDICATION: year old woman with cirrhosis.
# 7                                                     NaN
# 12                                                    NaN
# 14      INDICATION: -year-old female with shortness of...
# 19      INDICATION: F with wheezing and dyspnea. Asses...
# ...                                                   ...
# 227829                                                NaN
# 227830  INDICATION: Patient with intubation, evaluatio...
# 227832                                                NaN
# 227833                                                NaN
# 227834  INDICATION: -year-old female intubated for hea...
#
#                                               COMPARISON:  \
# 3                    COMPARISON: Radiographs from , and .
# 7       COMPARISON: Multiple prior radiographs of the ...
# 12            COMPARISON: CT torso and chest radiograph .
# 14                COMPARISON: Chest radiograph from and .
# 19        COMPARISON: chest radiograph. chest radiograph.
# ...                                                   ...
# 227829                                                NaN
# 227830                                  COMPARISON: None.
# 227832                            COMPARISON: radiograph.
# 227833  COMPARISON: Prior chest radiograph from earlie...
# 227834               COMPARISON: Chest radiographs from .
#
#                                                 FINDINGS:  \
# 3       FINDINGS: The lungs are clear of focal consoli...
# 7       FINDINGS: Lung volumes remain low. There are i...
# 12      FINDINGS: Lung volumes are low. This results i...
# 14                                                    NaN
# 19      FINDINGS: In comparison to study performed on ...
# ...                                                   ...
# 227829                                                NaN
# 227830  FINDINGS: ET tube ends 4.7 cm above the carina...
# 227832  FINDINGS: There has been interval extubation a...
# 227833  FINDINGS: Portable supine AP view of the chest...
# 227834  FINDINGS: The ET tube terminates approximately...
#
#                           EXAMINATION:  \
# 3                                  NaN
# 7                                  NaN
# 12                                 NaN
# 14                                 NaN
# 19      EXAMINATION: Chest radiograph.
# ...                                ...
# 227829                             NaN
# 227830                             NaN
# 227832                             NaN
# 227833                             NaN
# 227834                             NaN
#
#                                                TECHNIQUE:  \
# 3       TECHNIQUE: Frontal chest radiographs were obta...
# 7       TECHNIQUE: Portable semi-upright AP radiograph...
# 12          TECHNIQUE: Semi-upright AP view of the chest.
# 14                                                    NaN
# 19      TECHNIQUE: Single portable upright frontal che...
# ...                                                   ...
# 227829                                                NaN
# 227830                                                NaN
# 227832                                                NaN
# 227833                                                NaN
# 227834   TECHNIQUE: Single AP portable exam on the chest.
#
#                                                  HISTORY:  \
# 3                                                     NaN
# 7       HISTORY: Leukocytosis, low-grade temperature, ...
# 12           HISTORY: Dyspnea and history of lung cancer.
# 14                                                    NaN
# 19                                                    NaN
# ...                                                   ...
# 227829                                                NaN
# 227830                                                NaN
# 227832                                                NaN
# 227833                                                NaN
# 227834                                                NaN
#
#                                                 WET READ:  \
# 3                                                     NaN
# 7                                                     NaN
# 12                                                    NaN
# 14                                                    NaN
# 19      WET READ: 6:47 AM 1. New mild pulmonary edema ...
# ...                                                   ...
# 227829                                                NaN
# 227830                                                NaN
# 227832                                                NaN
# 227833                                                NaN
# 227834                                                NaN
#
#        CHEST RADIOGRAPH INDICATION:
# 3                               NaN
# 7                               NaN
# 12                              NaN
# 14                              NaN
# 19                              NaN
# ...                             ...
# 227829                          NaN
# 227830                          NaN
# 227832                          NaN
# 227833                          NaN
# 227834                          NaN
#
# [102675 rows x 14 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102675 entries, 3 to 227834
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   subject_id                    102675 non-null  int64
#  1   study_id                      102675 non-null  int64
#  2   path                          102675 non-null  object
#  3   content                       102675 non-null  object
#  4   cleaned_content               102675 non-null  object
#  5   IMPRESSION:                   75268 non-null   object
#  6   INDICATION:                   63133 non-null   object
#  7   COMPARISON:                   60257 non-null   object
#  8   FINDINGS:                     52918 non-null   object
#  9   EXAMINATION:                  46559 non-null   object
#  10  TECHNIQUE:                    24673 non-null   object
#  11  HISTORY:                      15722 non-null   object
#  12  WET READ:                     9205 non-null    object
#  13  CHEST RADIOGRAPH INDICATION:  6351 non-null    object
# dtypes: int64(2), object(12)
# memory usage: 11.8+ MB

# %%
# write out the updated dataframe to a new csv file
df_new.to_csv('cleaned_single_image_study_id.csv', index=False)
